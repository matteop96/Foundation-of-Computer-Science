# %%
#vado ad importare le librerie che mi serviranno nello svolgimento del progetto:
import pandas as pd
import numpy as np
from datetime import datetime

# %%
##Punto 1

# %%
#vado a caricare il dataset loan_lenders con pandas, in modo tale da renderlo più facilmente trattabile. 
loan_lenders = pd.read_csv("/Users/matteo/Downloads/loans_lenders.csv")
loan_lenders.head()
# Out:
#    loan_id                                            lenders
# 0   483693  muc888, sam4326, camaran3922, lachheb1865, reb...
# 1   483738  muc888, nora3555, williammanashi, barbara5610,...
# 2   485000  muc888, terrystl, richardandsusan8352, sherri4...
# 3   486087  muc888, james5068, rudi5955, daniel9859, don92...
# 4   534428  muc888, niki3008, teresa9174, mike4896, david7...

# %%
#devo svolgere la normalizzazione di questo dataframe
#nello split senza mettere str, non me lo farebbe fare, perchè lo considera come una serie
loan_lenders_normalizzati = loan_lenders.assign(lenders = loan_lenders['lenders'].str.split(',')).explode('lenders')
#così facendo li ho trasformati in tipo string da series che erano, e ho considerato come delimitatore la virgola.
#ora quello che devo fare è considerare ogni

# %%
loan_lenders_normalizzati
# Out:
#          loan_id             lenders
# 0         483693              muc888
# 0         483693             sam4326
# 0         483693         camaran3922
# 0         483693         lachheb1865
# 0         483693         rebecca3499
# ...          ...                 ...
# 1387430  1206425   trogdorfamily7622
# 1387430  1206425           danny6470
# 1387430  1206425             don6118
# 1387431  1206486            alan5175
# 1387431  1206486         amy38101311
#
# [28293931 rows x 2 columns]

# %%
#noto che ci dovrebbero essere degli spazi in lenders, quindi provvedo a toglierli con la funzione replace(), da considerare che opero con una stringa e utilizzerò str.replace()
#questo andrebbe a creare problemi in un momento successivo nella ricerca singola di eventuali lender
loan_lenders_normalizzati['lenders'] = loan_lenders_normalizzati['lenders'].str.replace(" ", "")

# %%
loan_lenders_normalizzati
# Out:
#          loan_id            lenders
# 0         483693             muc888
# 0         483693            sam4326
# 0         483693        camaran3922
# 0         483693        lachheb1865
# 0         483693        rebecca3499
# ...          ...                ...
# 1387430  1206425  trogdorfamily7622
# 1387430  1206425          danny6470
# 1387430  1206425            don6118
# 1387431  1206486           alan5175
# 1387431  1206486        amy38101311
#
# [28293931 rows x 2 columns]

# %%
##Punto 2

# %%
#vado ad eseguire la 2 task
#carico il dataset loans:
loans = pd.read_csv("/Users/matteo/Downloads/loans.csv")
loans.head()
# Out:
#    loan_id       loan_name original_language  \
# 0   657307            Aivy           English
# 1   657259  Idalia Marizza           Spanish
# 2   658010           Aasia           English
# 3   659347         Gulmira           Russian
# 4   656933         Ricky\t           English
#
#                                          description  \
# 0  Aivy, 21 years of age, is single and lives in ...
# 1  Doña Idalia, esta casada, tiene 57 años de eda...
# 2  Aasia is a 45-year-old married lady and she ha...
# 3  Гулмире 36 лет, замужем, вместе с супругом вос...
# 4  Ricky is a farmer who currently cultivates his...
#
#                               description_translated  funded_amount  \
# 0                                                NaN          125.0
# 1  Idalia, 57, is married and lives with her husb...          400.0
# 2                                                NaN          400.0
# 3  Gulmira is 36 years old and married.  She and ...          625.0
# 4                                                NaN          425.0
#
#    loan_amount  status  activity_name  sector_name  ...  \
# 0        125.0  funded  General Store       Retail  ...
# 1        400.0  funded  Used Clothing     Clothing  ...
# 2        400.0  funded  General Store       Retail  ...
# 3        625.0  funded        Farming  Agriculture  ...
# 4        425.0  funded        Farming  Agriculture  ...
#
#                      raised_time lender_term num_lenders_total  \
# 0  2014-01-15 04:48:22.000 +0000         7.0                 3
# 1  2014-02-25 06:42:06.000 +0000         8.0                11
# 2  2014-01-24 23:06:18.000 +0000        14.0                16
# 3  2014-01-22 05:29:28.000 +0000        14.0                21
# 4  2014-01-14 17:29:27.000 +0000         7.0                15
#
#   num_journal_entries num_bulk_entries  \
# 0                   2                1
# 1                   2                1
# 2                   2                1
# 3                   2                1
# 4                   2                1
#
#                                                 tags borrower_genders  \
# 0                                                NaN           female
# 1                                                NaN           female
# 2  #Woman Owned Biz, #Supporting Family, user_fav...           female
# 3                                      user_favorite           female
# 4           #Animals, #Eco-friendly, #Sustainable Ag             male
#
#    borrower_pictured repayment_interval distribution_model
# 0               true          irregular      field_partner
# 1               true            monthly      field_partner
# 2               true            monthly      field_partner
# 3               true            monthly      field_partner
# 4               true             bullet      field_partner
#
# [5 rows x 31 columns]

# %%
#devo trovare la differenza tra disburse time e planned expiration time, andiamo a vedere come sono raccolte nella tabella:
list(loans)
# Out:
# ['loan_id',
#  'loan_name',
#  'original_language',
#  'description',
#  'description_translated',
#  'funded_amount',
#  'loan_amount',
#  'status',
#  'activity_name',
#  'sector_name',
#  'loan_use',
#  'country_code',
#  'country_name',
#  'town_name',
#  'currency_policy',
#  'currency_exchange_coverage_rate',
#  'currency',
#  'partner_id',
#  'posted_time',
#  'planned_expiration_time',
#  'disburse_time',
#  'raised_time',
#  'lender_term',
#  'num_lenders_total',
#  'num_journal_entries',
#  'num_bulk_entries',
#  'tags',
#  'borrower_genders',
#  'borrower_pictured',
#  'repayment_interval',
#  'distribution_model']

# %%
loans[['disburse_time', 'planned_expiration_time']]
# Out:
#                          disburse_time        planned_expiration_time
# 0        2013-12-22 08:00:00.000 +0000  2014-02-14 03:30:06.000 +0000
# 1        2013-12-20 08:00:00.000 +0000  2014-03-26 22:25:07.000 +0000
# 2        2014-01-09 08:00:00.000 +0000  2014-02-15 21:10:05.000 +0000
# 3        2014-01-17 08:00:00.000 +0000  2014-02-21 03:10:02.000 +0000
# 4        2013-12-17 08:00:00.000 +0000  2014-02-13 06:10:02.000 +0000
# ...                                ...                            ...
# 1419602  2015-11-23 08:00:00.000 +0000  2016-01-02 01:00:03.000 +0000
# 1419603  2015-11-24 08:00:00.000 +0000  2016-01-02 16:40:07.000 +0000
# 1419604  2015-11-13 08:00:00.000 +0000  2016-01-03 22:20:04.000 +0000
# 1419605  2015-11-03 08:00:00.000 +0000  2016-01-05 08:50:02.000 +0000
# 1419606  2015-11-03 08:00:00.000 +0000  2016-01-03 20:50:06.000 +0000
#
# [1419607 rows x 2 columns]

# %%
loans['disburse_time_date'] = pd.to_datetime(loans['disburse_time'], format= "%Y-%m-%d %H:%M:%S.%f", errors='raise')
loans['planned_expiration_time_date'] = pd.to_datetime(loans['planned_expiration_time'], format= "%Y-%m-%d %H:%M:%S.%f", errors='raise')
loans.head()
# Out:
#    loan_id       loan_name original_language  \
# 0   657307            Aivy           English
# 1   657259  Idalia Marizza           Spanish
# 2   658010           Aasia           English
# 3   659347         Gulmira           Russian
# 4   656933         Ricky\t           English
#
#                                          description  \
# 0  Aivy, 21 years of age, is single and lives in ...
# 1  Doña Idalia, esta casada, tiene 57 años de eda...
# 2  Aasia is a 45-year-old married lady and she ha...
# 3  Гулмире 36 лет, замужем, вместе с супругом вос...
# 4  Ricky is a farmer who currently cultivates his...
#
#                               description_translated  funded_amount  \
# 0                                                NaN          125.0
# 1  Idalia, 57, is married and lives with her husb...          400.0
# 2                                                NaN          400.0
# 3  Gulmira is 36 years old and married.  She and ...          625.0
# 4                                                NaN          425.0
#
#    loan_amount  status  activity_name  sector_name  ... num_lenders_total  \
# 0        125.0  funded  General Store       Retail  ...                 3
# 1        400.0  funded  Used Clothing     Clothing  ...                11
# 2        400.0  funded  General Store       Retail  ...                16
# 3        625.0  funded        Farming  Agriculture  ...                21
# 4        425.0  funded        Farming  Agriculture  ...                15
#
#   num_journal_entries num_bulk_entries  \
# 0                   2                1
# 1                   2                1
# 2                   2                1
# 3                   2                1
# 4                   2                1
#
#                                                 tags borrower_genders  \
# 0                                                NaN           female
# 1                                                NaN           female
# 2  #Woman Owned Biz, #Supporting Family, user_fav...           female
# 3                                      user_favorite           female
# 4           #Animals, #Eco-friendly, #Sustainable Ag             male
#
#    borrower_pictured repayment_interval  distribution_model  \
# 0               true          irregular       field_partner
# 1               true            monthly       field_partner
# 2               true            monthly       field_partner
# 3               true            monthly       field_partner
# 4               true             bullet       field_partner
#
#          disburse_time_date planned_expiration_time_date
# 0 2013-12-22 08:00:00+00:00    2014-02-14 03:30:06+00:00
# 1 2013-12-20 08:00:00+00:00    2014-03-26 22:25:07+00:00
# 2 2014-01-09 08:00:00+00:00    2014-02-15 21:10:05+00:00
# 3 2014-01-17 08:00:00+00:00    2014-02-21 03:10:02+00:00
# 4 2013-12-17 08:00:00+00:00    2014-02-13 06:10:02+00:00
#
# [5 rows x 33 columns]

# %%
loans['duration'] = loans['planned_expiration_time_date'] - loans['disburse_time_date']
loans.head()
# Out:
#    loan_id       loan_name original_language  \
# 0   657307            Aivy           English
# 1   657259  Idalia Marizza           Spanish
# 2   658010           Aasia           English
# 3   659347         Gulmira           Russian
# 4   656933         Ricky\t           English
#
#                                          description  \
# 0  Aivy, 21 years of age, is single and lives in ...
# 1  Doña Idalia, esta casada, tiene 57 años de eda...
# 2  Aasia is a 45-year-old married lady and she ha...
# 3  Гулмире 36 лет, замужем, вместе с супругом вос...
# 4  Ricky is a farmer who currently cultivates his...
#
#                               description_translated  funded_amount  \
# 0                                                NaN          125.0
# 1  Idalia, 57, is married and lives with her husb...          400.0
# 2                                                NaN          400.0
# 3  Gulmira is 36 years old and married.  She and ...          625.0
# 4                                                NaN          425.0
#
#    loan_amount  status  activity_name  sector_name  ... num_journal_entries  \
# 0        125.0  funded  General Store       Retail  ...                   2
# 1        400.0  funded  Used Clothing     Clothing  ...                   2
# 2        400.0  funded  General Store       Retail  ...                   2
# 3        625.0  funded        Farming  Agriculture  ...                   2
# 4        425.0  funded        Farming  Agriculture  ...                   2
#
#   num_bulk_entries                                               tags  \
# 0                1                                                NaN
# 1                1                                                NaN
# 2                1  #Woman Owned Biz, #Supporting Family, user_fav...
# 3                1                                      user_favorite
# 4                1           #Animals, #Eco-friendly, #Sustainable Ag
#
#   borrower_genders borrower_pictured  repayment_interval distribution_model  \
# 0           female              true           irregular      field_partner
# 1           female              true             monthly      field_partner
# 2           female              true             monthly      field_partner
# 3           female              true             monthly      field_partner
# 4             male              true              bullet      field_partner
#
#          disburse_time_date planned_expiration_time_date         duration
# 0 2013-12-22 08:00:00+00:00    2014-02-14 03:30:06+00:00 53 days 19:30:06
# 1 2013-12-20 08:00:00+00:00    2014-03-26 22:25:07+00:00 96 days 14:25:07
# 2 2014-01-09 08:00:00+00:00    2014-02-15 21:10:05+00:00 37 days 13:10:05
# 3 2014-01-17 08:00:00+00:00    2014-02-21 03:10:02+00:00 34 days 19:10:02
# 4 2013-12-17 08:00:00+00:00    2014-02-13 06:10:02+00:00 57 days 22:10:02
#
# [5 rows x 34 columns]

# %%
#sono presenti vari missing values nelle colonna colonna distribution che siamo andati a trovare, provvedo quindi ad eliminare tutti i missing values presenti nella colonna di riferimento
loans.isnull().sum()
# Out:
# loan_id                                 0
# loan_name                           47558
# original_language                   43251
# description                         43285
# description_translated             452678
# funded_amount                           0
# loan_amount                             0
# status                                  0
# activity_name                           0
# sector_name                             0
# loan_use                            43273
# country_code                            9
# country_name                            0
# town_name                          161758
# currency_policy                         0
# currency_exchange_coverage_rate    321526
# currency                                0
# partner_id                          16790
# posted_time                             0
# planned_expiration_time            371834
# disburse_time                        2813
# raised_time                         64282
# lender_term                            24
# num_lenders_total                       0
# num_journal_entries                     0
# num_bulk_entries                        0
# tags                               784054
# borrower_genders                    43251
# borrower_pictured                   43251
# repayment_interval                      0
# distribution_model                      0
# disburse_time_date                   2813
# planned_expiration_time_date       371834
# duration                           374645
# dtype: int64

# %%
#andiamo a verificare che entrambe le colonne abbiano presenti dei casi di missing per poi dare la duration come missing:
missing_loans = loans.loc[:,['disburse_time_date','planned_expiration_time_date', 'duration']]
missing_loans.head()
# Out:
#          disburse_time_date planned_expiration_time_date         duration
# 0 2013-12-22 08:00:00+00:00    2014-02-14 03:30:06+00:00 53 days 19:30:06
# 1 2013-12-20 08:00:00+00:00    2014-03-26 22:25:07+00:00 96 days 14:25:07
# 2 2014-01-09 08:00:00+00:00    2014-02-15 21:10:05+00:00 37 days 13:10:05
# 3 2014-01-17 08:00:00+00:00    2014-02-21 03:10:02+00:00 34 days 19:10:02
# 4 2013-12-17 08:00:00+00:00    2014-02-13 06:10:02+00:00 57 days 22:10:02

# %%
#così facendo posso vedere che effettivamente se un elemento è mancante, allora anche la colonna duration sarà mancante
null_data = missing_loans[missing_loans.isnull().any(axis=1)]
null_data
# Out:
#                disburse_time_date planned_expiration_time_date duration
# 64      2010-11-18 08:00:00+00:00                          NaT      NaT
# 65      2010-11-25 08:00:00+00:00                          NaT      NaT
# 66      2010-11-25 08:00:00+00:00                          NaT      NaT
# 67      2010-11-16 08:00:00+00:00                          NaT      NaT
# 69      2010-11-10 08:00:00+00:00                          NaT      NaT
# ...                           ...                          ...      ...
# 1419523 2005-04-14 05:27:55+00:00                          NaT      NaT
# 1419524                       NaT    2017-02-09 23:07:54+00:00      NaT
# 1419525                       NaT    2015-09-21 08:06:19+00:00      NaT
# 1419538                       NaT    2017-02-25 20:21:21+00:00      NaT
# 1419564                       NaT    2016-09-30 18:49:53+00:00      NaT
#
# [374645 rows x 3 columns]

# %%
##Punto 3

# %%
#devo trovare i landers che hanno finanziato minimo 2 volte:
#ho il dataset normalizzato loan_lenders_normalizzati che contiene i nomi dei lenders, ed ho il dataset loan che contiene
#tutti i prestiti che effettivamente sono stati finanziati, per prima cosa unisco i due datasets

# %%
loan_lenders_normalizzati.head()
# Out:
#    loan_id      lenders
# 0   483693       muc888
# 0   483693      sam4326
# 0   483693  camaran3922
# 0   483693  lachheb1865
# 0   483693  rebecca3499

# %%
loans.head()
# Out:
#    loan_id       loan_name original_language  \
# 0   657307            Aivy           English
# 1   657259  Idalia Marizza           Spanish
# 2   658010           Aasia           English
# 3   659347         Gulmira           Russian
# 4   656933         Ricky\t           English
#
#                                          description  \
# 0  Aivy, 21 years of age, is single and lives in ...
# 1  Doña Idalia, esta casada, tiene 57 años de eda...
# 2  Aasia is a 45-year-old married lady and she ha...
# 3  Гулмире 36 лет, замужем, вместе с супругом вос...
# 4  Ricky is a farmer who currently cultivates his...
#
#                               description_translated  funded_amount  \
# 0                                                NaN          125.0
# 1  Idalia, 57, is married and lives with her husb...          400.0
# 2                                                NaN          400.0
# 3  Gulmira is 36 years old and married.  She and ...          625.0
# 4                                                NaN          425.0
#
#    loan_amount  status  activity_name  sector_name  ... num_journal_entries  \
# 0        125.0  funded  General Store       Retail  ...                   2
# 1        400.0  funded  Used Clothing     Clothing  ...                   2
# 2        400.0  funded  General Store       Retail  ...                   2
# 3        625.0  funded        Farming  Agriculture  ...                   2
# 4        425.0  funded        Farming  Agriculture  ...                   2
#
#   num_bulk_entries                                               tags  \
# 0                1                                                NaN
# 1                1                                                NaN
# 2                1  #Woman Owned Biz, #Supporting Family, user_fav...
# 3                1                                      user_favorite
# 4                1           #Animals, #Eco-friendly, #Sustainable Ag
#
#   borrower_genders borrower_pictured  repayment_interval distribution_model  \
# 0           female              true           irregular      field_partner
# 1           female              true             monthly      field_partner
# 2           female              true             monthly      field_partner
# 3           female              true             monthly      field_partner
# 4             male              true              bullet      field_partner
#
#          disburse_time_date planned_expiration_time_date         duration
# 0 2013-12-22 08:00:00+00:00    2014-02-14 03:30:06+00:00 53 days 19:30:06
# 1 2013-12-20 08:00:00+00:00    2014-03-26 22:25:07+00:00 96 days 14:25:07
# 2 2014-01-09 08:00:00+00:00    2014-02-15 21:10:05+00:00 37 days 13:10:05
# 3 2014-01-17 08:00:00+00:00    2014-02-21 03:10:02+00:00 34 days 19:10:02
# 4 2013-12-17 08:00:00+00:00    2014-02-13 06:10:02+00:00 57 days 22:10:02
#
# [5 rows x 34 columns]

# %%
loans_e_lenders_uniti = pd.merge(loan_lenders_normalizzati, loans[['loan_id', 'status']], on = 'loan_id')
loans_e_lenders_uniti
# Out:
#           loan_id            lenders  status
# 0          483693             muc888  funded
# 1          483693            sam4326  funded
# 2          483693        camaran3922  funded
# 3          483693        lachheb1865  funded
# 4          483693        rebecca3499  funded
# ...           ...                ...     ...
# 28293907  1206425  trogdorfamily7622  funded
# 28293908  1206425          danny6470  funded
# 28293909  1206425            don6118  funded
# 28293910  1206486           alan5175  funded
# 28293911  1206486        amy38101311  funded
#
# [28293912 rows x 3 columns]

# %%
#mi rendo conto che nello status non abbiamo tutti con esito positivo, che sarebbe funded, quindi per non rendere troppo complicata
#il comando del count successivo, considero solamente i casi di funded:
loans_e_lenders_uniti.status.unique()
# Out:
# array(['funded', 'expired', 'refunded', 'fundRaising'], dtype=object)

# %%
loans_e_lenders_uniti_funded = loans_e_lenders_uniti[loans_e_lenders_uniti['status'] == 'funded']
loans_e_lenders_uniti_funded.head()
# Out:
#    loan_id      lenders  status
# 0   483693       muc888  funded
# 1   483693      sam4326  funded
# 2   483693  camaran3922  funded
# 3   483693  lachheb1865  funded
# 4   483693  rebecca3499  funded

# %%
loans_e_lenders_uniti_funded_1= loans_e_lenders_uniti_funded.groupby('lenders')['lenders'].size()
loans_e_lenders_uniti_funded_1
# Out:
# lenders
# 000                 39
# 00000               38
# 0002                70
# 00mike00             1
# 0101craign0101      71
#                   ...
# zzmcfate          1648
# zzpaghetti9994       1
# zzrvmf8538          13
# zzzsai               4
# zzzworld             1
# Name: lenders, Length: 1368261, dtype: int64

# %%
#mettendo come minimo uguale a 2, trovo i lenders che hanno finanziato con successo minimo due volte:
loans_e_lenders_uniti_funded_1[loans_e_lenders_uniti_funded_1 >= 2]
# Out:
# lenders
# 000                 39
# 00000               38
# 0002                70
# 0101craign0101      71
# 0132575              4
#                   ...
# zzinnia             27
# zzivnk7094           4
# zzmcfate          1648
# zzrvmf8538          13
# zzzsai               4
# Name: lenders, Length: 893981, dtype: int64

# %%
##Punto 4
#Per ciascun paese, calcolare quanti prestiti hanno coinvolto quel paese come mutuatari

# %%
locations = pd.read_csv("/Users/matteo/Downloads/locations.csv")
locations.head()
# Out:
#                                   address_components   formatted_address  \
# 0  [{'long_name': 'Managua', 'short_name': 'Manag...  Managua, Nicaragua
# 1  [{'long_name': 'Lahore', 'short_name': 'Lahore...    Lahore, Pakistan
# 2  [{'long_name': 'Kaduna', 'short_name': 'Kaduna...     Kaduna, Nigeria
# 3  [{'long_name': 'Cusco', 'short_name': 'Cusco',...         Cusco, Peru
# 4  [{'long_name': 'León', 'short_name': 'León', '...     León, Nicaragua
#
#    geometry.bounds.northeast.lat  geometry.bounds.northeast.lng  \
# 0                      12.175357                     -86.125088
# 1                      31.698486                      74.587397
# 2                      10.616996                       7.508812
# 3                     -13.497391                     -71.853332
# 4                      12.460966                     -86.843405
#
#    geometry.bounds.southwest.lat  geometry.bounds.southwest.lng  \
# 0                      12.019961                     -86.391833
# 1                      31.267394                      74.115539
# 2                      10.397157                       7.349789
# 3                     -13.562648                     -72.025166
# 4                      12.407026                     -86.920753
#
#    geometry.location.lat  geometry.location.lng geometry.location_type  \
# 0              12.114993             -86.236174            APPROXIMATE
# 1              31.520370              74.358747            APPROXIMATE
# 2              10.510464               7.416505            APPROXIMATE
# 3             -13.531950             -71.967463            APPROXIMATE
# 4              12.431553             -86.872215            APPROXIMATE
#
#    geometry.viewport.northeast.lat  geometry.viewport.northeast.lng  \
# 0                        12.175357                       -86.125088
# 1                        31.698486                        74.587397
# 2                        10.616996                         7.508812
# 3                       -13.497391                       -71.853332
# 4                        12.460966                       -86.843405
#
#    geometry.viewport.southwest.lat  geometry.viewport.southwest.lng  \
# 0                        12.019961                       -86.391833
# 1                        31.267394                        74.115539
# 2                        10.397157                         7.349789
# 3                       -13.562648                       -72.025166
# 4                        12.407026                       -86.920753
#
#         location_name partial_match                     place_id  \
# 0  Managua, Nicaragua           NaN  ChIJC4gH2Q1WcY8RakxPFKL0Xmw
# 1    Lahore, Pakistan           NaN  ChIJ2QeB5YMEGTkRYiR-zGy-OsI
# 2     Kaduna, Nigeria           NaN  ChIJdRc3NFg1TRARdOG_mpeVAUg
# 3         Cusco, Peru           NaN  ChIJMYRZJtjVbZERXTEYI8yWqSo
# 4     Leon, Nicaragua           NaN  ChIJd3qPu5IfcY8RPDHqZG_AtTo
#
#                        types
# 0  ['locality', 'political']
# 1  ['locality', 'political']
# 2  ['locality', 'political']
# 3  ['locality', 'political']
# 4  ['locality', 'political']

# %%
loans['country_name']
# Out:
# 0          Philippines
# 1             Honduras
# 2             Pakistan
# 3           Kyrgyzstan
# 4          Philippines
#               ...
# 1419602          Kenya
# 1419603    Philippines
# 1419604          Ghana
# 1419605    Philippines
# 1419606     Madagascar
# Name: country_name, Length: 1419607, dtype: object

# %%
#sapendo che prima ci sono stati dei casi dove la duration è stata nulla, considero solamente i prestiti dove la durata è stata calcolata:
loans_nomissing = loans[loans.duration.notnull()]

# %%
#eseguo il groupby per tutto per trovare il numero di country
loans_nomissing.groupby('country_name').size()
# Out:
# country_name
# Afghanistan        2
# Albania         3075
# Armenia        12809
# Azerbaijan      4026
# Belize           218
#                ...
# Vanuatu            4
# Vietnam        16371
# Yemen           4184
# Zambia          1277
# Zimbabwe        5075
# Length: 90, dtype: int64

# %%
#Punto 5

# %%
#osservo dalla serie di informazioni del dataset loans, che è presenta una colonna chiamata loan_amount che rappresenta l'ammontare di denaro concesso in prestito
list(loans)
# Out:
# ['loan_id',
#  'loan_name',
#  'original_language',
#  'description',
#  'description_translated',
#  'funded_amount',
#  'loan_amount',
#  'status',
#  'activity_name',
#  'sector_name',
#  'loan_use',
#  'country_code',
#  'country_name',
#  'town_name',
#  'currency_policy',
#  'currency_exchange_coverage_rate',
#  'currency',
#  'partner_id',
#  'posted_time',
#  'planned_expiration_time',
#  'disburse_time',
#  'raised_time',
#  'lender_term',
#  'num_lenders_total',
#  'num_journal_entries',
#  'num_bulk_entries',
#  'tags',
#  'borrower_genders',
#  'borrower_pictured',
#  'repayment_interval',
#  'distribution_model',
#  'disburse_time_date',
#  'planned_expiration_time_date',
#  'duration']

# %%
#eseguo un groupby per trovare per ogni nazione l'importo di denaro preso in prestito, applicando un sum() per ottenere il totale:
loans_amount = loans_nomissing.groupby('country_code')['loan_amount'].sum()
loans_amount
# Out:
# country_code
# AF       14000.0
# AL     4307350.0
# AM    20579275.0
# AZ     6839400.0
# BF     3990450.0
#          ...
# XK     3083025.0
# YE     3430100.0
# ZA      886150.0
# ZM     1978975.0
# ZW     4921625.0
# Name: loan_amount, Length: 89, dtype: float64

# %%
#Punto 6

# %%
#dobbiamo calcolare come il punto precedente ma come percentuale del totale dell'ammonatare totale del prestito:

# %%
#Per prima cosa calcolo il totale dei prestiti:
loans_tot = loans_nomissing['loan_amount'].sum()
loans_tot
# Out:
# 889804100.0

# %%
loans_amount_percentuale = loans_nomissing.groupby('country_name')['loan_amount'].sum().reset_index()
loans_amount_percentuale['loan_amount'] = loans_amount_percentuale['loan_amount']/loans_tot*100
loans_amount_percentuale
# Out:
#    country_name  loan_amount
# 0   Afghanistan     0.001573
# 1       Albania     0.484078
# 2       Armenia     2.312787
# 3    Azerbaijan     0.768641
# 4        Belize     0.016877
# ..          ...          ...
# 85      Vanuatu     0.001040
# 86      Vietnam     2.303319
# 87        Yemen     0.385489
# 88       Zambia     0.222406
# 89     Zimbabwe     0.553113
#
# [90 rows x 2 columns]

# %%
#Punto 7

# %%
#dobbiamo eseguire i punti precedenti ma legati ad ogni singolo anno su disburse_time.
#la prima cosa che devo fare è lavorare su disburse_time ottenere ogni singolo anno.

# %%
loans_nomissing["disburse_time_new"] = pd.to_datetime(loans_nomissing["disburse_time"])
loans_nomissing["year"] = loans_nomissing["disburse_time_new"].dt.year
loans_nomissing
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#          loan_id           loan_name original_language  \
# 0         657307                Aivy           English
# 1         657259      Idalia Marizza           Spanish
# 2         658010               Aasia           English
# 3         659347             Gulmira           Russian
# 4         656933             Ricky\t           English
# ...          ...                 ...               ...
# 1419602   988180                 NaN               NaN
# 1419603   988213             Perlita           English
# 1419604   989109  Okyeso Nyame Group           English
# 1419605   989143            Exequila           English
# 1419606   989240               Lydia            French
#
#                                                description  \
# 0        Aivy, 21 years of age, is single and lives in ...
# 1        Doña Idalia, esta casada, tiene 57 años de eda...
# 2        Aasia is a 45-year-old married lady and she ha...
# 3        Гулмире 36 лет, замужем, вместе с супругом вос...
# 4        Ricky is a farmer who currently cultivates his...
# ...                                                    ...
# 1419602                                                NaN
# 1419603  Perlita is 52 years old, married and has three...
# 1419604  Okyeso Nyame group will begin its third cycle ...
# 1419605  Exequila  is from San Miguel, Bohol. She is in...
# 1419606  Lydia a 37ans et habite dans une zone rurale. ...
#
#                                     description_translated  funded_amount  \
# 0                                                      NaN          125.0
# 1        Idalia, 57, is married and lives with her husb...          400.0
# 2                                                      NaN          400.0
# 3        Gulmira is 36 years old and married.  She and ...          625.0
# 4                                                      NaN          425.0
# ...                                                    ...            ...
# 1419602                                                NaN          400.0
# 1419603  Perlita is 52 years old, married and has three...          300.0
# 1419604  Okyeso Nyame group will begin its third cycle ...         2425.0
# 1419605  Exequila  is from San Miguel, Bohol. She is in...          100.0
# 1419606  Lydia is 37 years old and lives in a rural are...          175.0
#
#          loan_amount  status  activity_name  sector_name  ...  \
# 0              125.0  funded  General Store       Retail  ...
# 1              400.0  funded  Used Clothing     Clothing  ...
# 2              400.0  funded  General Store       Retail  ...
# 3              625.0  funded        Farming  Agriculture  ...
# 4              425.0  funded        Farming  Agriculture  ...
# ...              ...     ...            ...          ...  ...
# 1419602        400.0  funded      Tailoring     Services  ...
# 1419603        300.0  funded           Pigs  Agriculture  ...
# 1419604       2425.0  funded         Bakery         Food  ...
# 1419605        100.0  funded        Farming  Agriculture  ...
# 1419606        175.0  funded         Sewing     Services  ...
#
#                                                       tags  \
# 0                                                      NaN
# 1                                                      NaN
# 2        #Woman Owned Biz, #Supporting Family, user_fav...
# 3                                            user_favorite
# 4                 #Animals, #Eco-friendly, #Sustainable Ag
# ...                                                    ...
# 1419602        #Parent, #Repeat Borrower, #Woman Owned Biz
# 1419603  #Animals, #Elderly, #Repeat Borrower, #Woman O...
# 1419604  user_favorite, #Parent, #Vegan, #Woman Owned B...
# 1419605                                                NaN
# 1419606                                                NaN
#
#                                    borrower_genders  \
# 0                                            female
# 1                                            female
# 2                                            female
# 3                                            female
# 4                                              male
# ...                                             ...
# 1419602                                         NaN
# 1419603                                      female
# 1419604  female, female, female, male, male, female
# 1419605                                      female
# 1419606                                      female
#
#                           borrower_pictured repayment_interval  \
# 0                                      true          irregular
# 1                                      true            monthly
# 2                                      true            monthly
# 3                                      true            monthly
# 4                                      true             bullet
# ...                                     ...                ...
# 1419602                                 NaN            monthly
# 1419603                                true          irregular
# 1419604  true, true, true, true, true, true          irregular
# 1419605                                true          irregular
# 1419606                                true            monthly
#
#         distribution_model        disburse_time_date  \
# 0            field_partner 2013-12-22 08:00:00+00:00
# 1            field_partner 2013-12-20 08:00:00+00:00
# 2            field_partner 2014-01-09 08:00:00+00:00
# 3            field_partner 2014-01-17 08:00:00+00:00
# 4            field_partner 2013-12-17 08:00:00+00:00
# ...                    ...                       ...
# 1419602      field_partner 2015-11-23 08:00:00+00:00
# 1419603      field_partner 2015-11-24 08:00:00+00:00
# 1419604      field_partner 2015-11-13 08:00:00+00:00
# 1419605      field_partner 2015-11-03 08:00:00+00:00
# 1419606      field_partner 2015-11-03 08:00:00+00:00
#
#         planned_expiration_time_date         duration  \
# 0          2014-02-14 03:30:06+00:00 53 days 19:30:06
# 1          2014-03-26 22:25:07+00:00 96 days 14:25:07
# 2          2014-02-15 21:10:05+00:00 37 days 13:10:05
# 3          2014-02-21 03:10:02+00:00 34 days 19:10:02
# 4          2014-02-13 06:10:02+00:00 57 days 22:10:02
# ...                              ...              ...
# 1419602    2016-01-02 01:00:03+00:00 39 days 17:00:03
# 1419603    2016-01-02 16:40:07+00:00 39 days 08:40:07
# 1419604    2016-01-03 22:20:04+00:00 51 days 14:20:04
# 1419605    2016-01-05 08:50:02+00:00 63 days 00:50:02
# 1419606    2016-01-03 20:50:06+00:00 61 days 12:50:06
#
#                 disburse_time_new  year
# 0       2013-12-22 08:00:00+00:00  2013
# 1       2013-12-20 08:00:00+00:00  2013
# 2       2014-01-09 08:00:00+00:00  2014
# 3       2014-01-17 08:00:00+00:00  2014
# 4       2013-12-17 08:00:00+00:00  2013
# ...                           ...   ...
# 1419602 2015-11-23 08:00:00+00:00  2015
# 1419603 2015-11-24 08:00:00+00:00  2015
# 1419604 2015-11-13 08:00:00+00:00  2015
# 1419605 2015-11-03 08:00:00+00:00  2015
# 1419606 2015-11-03 08:00:00+00:00  2015
#
# [1044962 rows x 36 columns]

# %%
loans_nomissing.groupby(['country_name', 'year']).size()
# Out:
# country_name  year
# Afghanistan   2015       1
#               2016       1
# Albania       2012     332
#               2013     507
#               2014     603
#                       ...
# Zimbabwe      2013     426
#               2014    2078
#               2015     600
#               2016     808
#               2017    1079
# Length: 516, dtype: int64

# %%
loans_nomissing.groupby(['country_name', 'year'])['loan_amount'].sum()
# Out:
# country_name  year
# Afghanistan   2015       6000.0
#               2016       8000.0
# Albania       2012     413000.0
#               2013     786950.0
#               2014     902550.0
#                         ...
# Zimbabwe      2013     678525.0
#               2014    1311575.0
#               2015     723625.0
#               2016     788600.0
#               2017    1237600.0
# Name: loan_amount, Length: 516, dtype: float64

# %%
loans_nomissing.groupby(['country_name', 'year'])['loan_amount'].sum()/loans_tot*100
# Out:
# country_name  year
# Afghanistan   2015    0.000674
#               2016    0.000899
# Albania       2012    0.046415
#               2013    0.088441
#               2014    0.101432
#                         ...
# Zimbabwe      2013    0.076256
#               2014    0.147400
#               2015    0.081324
#               2016    0.088626
#               2017    0.139087
# Name: loan_amount, Length: 516, dtype: float64

# %%
#Punto 8
#per ogni lenders trovare l'ammontare di denaro prestato, se un prestito fosse stato finanziato da più lenders allora sono da considerare di pari importo i finanziamenti dei singoli lenders

# %%
#vado a contare quanti lenders sono coinvolti per ogni loan, avendo diviso nel primo punto i lenders per ogni singolo loan, eseguo:
lenders_count = loan_lenders_normalizzati.groupby('loan_id').count()
lenders_count
# Out:
#          lenders
# loan_id
# 84             3
# 85             2
# 86             3
# 88             3
# 89             4
# ...          ...
# 1444051        1
# 1444053        1
# 1444058        1
# 1444063        1
# 1444065        1
#
# [1387432 rows x 1 columns]

# %%
lenders_count_e_amout = pd.merge(lenders_count, loans_nomissing, on = 'loan_id')
lenders_count_e_amout[['loan_id', 'lenders', 'loan_amount']].head()
# Out:
#    loan_id  lenders  loan_amount
# 0   358219       74       2300.0
# 1   358926       60       1925.0
# 2   359566       42       1400.0
# 3   360000       90       2875.0
# 4   360232       58       1800.0

# %%
#ora devo dividere l'ammontare del prestito per il numero di lenders che sono presenti e che lo hanno finanziato
lenders_count_e_amout['amount_unitario'] = lenders_count_e_amout['loan_amount']/lenders_count_e_amout['lenders']
lenders_count_e_amout.head()
# Out:
#    loan_id  lenders   loan_name original_language  \
# 0   358219       74  Mirismayil           English
# 1   358926       60        Saiq           English
# 2   359566       42    Alikishi           English
# 3   360000       90       Dagva           English
# 4   360232       58        Amil           English
#
#                                          description description_translated  \
# 0  Mirismayil is a 28-year-old trader who sells d...                    NaN
# 1  Saiq, 45, sells men's and women's clothes in t...                    NaN
# 2  Alikishi is a 59-year-old man who lives in Saa...                    NaN
# 3  Dagva is 31 years old and lives with his wife ...                    NaN
# 4  Amil is 38 years old, married and has two sons...                    NaN
#
#    funded_amount  loan_amount  status   activity_name  ... borrower_genders  \
# 0         2300.0       2300.0  funded  Clothing Sales  ...             male
# 1         1925.0       1925.0  funded        Clothing  ...             male
# 2         1400.0       1400.0  funded   Grocery Store  ...             male
# 3         2875.0       2875.0  funded  Transportation  ...             male
# 4         1800.0       1800.0  funded   General Store  ...             male
#
#   borrower_pictured repayment_interval distribution_model  \
# 0              true            monthly      field_partner
# 1              true            monthly      field_partner
# 2              true            monthly      field_partner
# 3              true            monthly      field_partner
# 4              true            monthly      field_partner
#
#          disburse_time_date planned_expiration_time_date          duration  \
# 0 2011-10-18 07:00:00+00:00    2012-02-11 22:50:58+00:00 116 days 15:50:58
# 1 2011-10-19 07:00:00+00:00    2012-01-30 08:01:57+00:00 103 days 01:01:57
# 2 2011-10-19 07:00:00+00:00    2012-02-09 01:35:52+00:00 112 days 18:35:52
# 3 2011-11-15 08:00:00+00:00    2012-02-03 21:30:05+00:00  80 days 13:30:05
# 4 2011-10-21 07:00:00+00:00    2012-02-09 01:35:52+00:00 110 days 18:35:52
#
#           disburse_time_new  year amount_unitario
# 0 2011-10-18 07:00:00+00:00  2011       31.081081
# 1 2011-10-19 07:00:00+00:00  2011       32.083333
# 2 2011-10-19 07:00:00+00:00  2011       33.333333
# 3 2011-11-15 08:00:00+00:00  2011       31.944444
# 4 2011-10-21 07:00:00+00:00  2011       31.034483
#
# [5 rows x 38 columns]

# %%
#avendo trovato l'ammontare per ogni singolo prestito, allora passo ad aggiungere il nome dei lenders per trovare per ogni lenders quanto effettivamente ha contribuito
lenders_e_amount_loans = pd.merge(lenders_count_e_amout, loan_lenders_normalizzati, on = 'loan_id', how = 'right')
lenders_e_amount_loans.head()
# Out:
#    loan_id  lenders_x   loan_name original_language  \
# 0   358219       74.0  Mirismayil           English
# 1   358219       74.0  Mirismayil           English
# 2   358219       74.0  Mirismayil           English
# 3   358219       74.0  Mirismayil           English
# 4   358219       74.0  Mirismayil           English
#
#                                          description description_translated  \
# 0  Mirismayil is a 28-year-old trader who sells d...                    NaN
# 1  Mirismayil is a 28-year-old trader who sells d...                    NaN
# 2  Mirismayil is a 28-year-old trader who sells d...                    NaN
# 3  Mirismayil is a 28-year-old trader who sells d...                    NaN
# 4  Mirismayil is a 28-year-old trader who sells d...                    NaN
#
#    funded_amount  loan_amount  status   activity_name  ... borrower_pictured  \
# 0         2300.0       2300.0  funded  Clothing Sales  ...              true
# 1         2300.0       2300.0  funded  Clothing Sales  ...              true
# 2         2300.0       2300.0  funded  Clothing Sales  ...              true
# 3         2300.0       2300.0  funded  Clothing Sales  ...              true
# 4         2300.0       2300.0  funded  Clothing Sales  ...              true
#
#   repayment_interval distribution_model        disburse_time_date  \
# 0            monthly      field_partner 2011-10-18 07:00:00+00:00
# 1            monthly      field_partner 2011-10-18 07:00:00+00:00
# 2            monthly      field_partner 2011-10-18 07:00:00+00:00
# 3            monthly      field_partner 2011-10-18 07:00:00+00:00
# 4            monthly      field_partner 2011-10-18 07:00:00+00:00
#
#   planned_expiration_time_date          duration         disburse_time_new  \
# 0    2012-02-11 22:50:58+00:00 116 days 15:50:58 2011-10-18 07:00:00+00:00
# 1    2012-02-11 22:50:58+00:00 116 days 15:50:58 2011-10-18 07:00:00+00:00
# 2    2012-02-11 22:50:58+00:00 116 days 15:50:58 2011-10-18 07:00:00+00:00
# 3    2012-02-11 22:50:58+00:00 116 days 15:50:58 2011-10-18 07:00:00+00:00
# 4    2012-02-11 22:50:58+00:00 116 days 15:50:58 2011-10-18 07:00:00+00:00
#
#      year  amount_unitario           lenders_y
# 0  2011.0        31.081081       james61968508
# 1  2011.0        31.081081       james61968508
# 2  2011.0        31.081081       james61968508
# 3  2011.0        31.081081  TippieMBAUIowaGFMA
# 4  2011.0        31.081081             tom1045
#
# [5 rows x 39 columns]

# %%
lenders_ammontare = lenders_e_amount_loans.groupby("lenders_y")["amount_unitario"].sum().reset_index()
lenders_ammontare.head()
# Out:
#         lenders_y  amount_unitario
# 0             000      1456.996604
# 1           00000         0.000000
# 2            0002       677.081981
# 3        00mike00        52.631579
# 4  0101craign0101       606.748996

# %%
#Punto 9
#For each country, compute the difference between the overall amount of money lent and the overall amount of money borrowed. Since the country of the lender is often unknown, you can assume that the true distribution among the countries is the same as the one computed from the rows where the country is known.

# %%
list(loans)
# Out:
# ['loan_id',
#  'loan_name',
#  'original_language',
#  'description',
#  'description_translated',
#  'funded_amount',
#  'loan_amount',
#  'status',
#  'activity_name',
#  'sector_name',
#  'loan_use',
#  'country_code',
#  'country_name',
#  'town_name',
#  'currency_policy',
#  'currency_exchange_coverage_rate',
#  'currency',
#  'partner_id',
#  'posted_time',
#  'planned_expiration_time',
#  'disburse_time',
#  'raised_time',
#  'lender_term',
#  'num_lenders_total',
#  'num_journal_entries',
#  'num_bulk_entries',
#  'tags',
#  'borrower_genders',
#  'borrower_pictured',
#  'repayment_interval',
#  'distribution_model',
#  'disburse_time_date',
#  'planned_expiration_time_date',
#  'duration']

# %%
#per prima cosa ho bisogno di sapere da dove provengono i prestiti a livello di nazioni:
lenders = pd.read_csv('/Users/matteo/Downloads/lenders.csv')
lenders.head()
# Out:
#    permanent_name display_name city state country_code  member_since  \
# 0        qian3013         Qian  NaN   NaN          NaN    1461300457
# 1       reena6733        Reena  NaN   NaN          NaN    1461300634
# 2         mai5982          Mai  NaN   NaN          NaN    1461300853
# 3  andrew86079135       Andrew  NaN   NaN          NaN    1461301091
# 4      nguyen6962       Nguyen  NaN   NaN          NaN    1461301154
#
#   occupation loan_because  loan_purchase_num invited_by  num_invited
# 0        NaN          NaN                1.0        NaN            0
# 1        NaN          NaN                9.0        NaN            0
# 2        NaN          NaN                NaN        NaN            0
# 3        NaN          NaN                5.0  Peter Tan            0
# 4        NaN          NaN                NaN        NaN            0

# %%
#mi rendo conto che nella colonna country_code trovo il codice di ogni nazione riferita ad ogni singolo lender
lenders['country_code'].unique()
# Out:
# array([nan, 'US', 'IN', 'AU', 'PL', 'BR', 'CN', 'FR', 'BG', 'AT', 'GB',
#        'ES', 'DE', 'BE', 'SK', 'IT', 'SE', 'JP', 'PK', 'LA', 'AR', 'HU',
#        'TR', 'LV', 'TW', 'MY', 'NL', 'GE', 'ID', 'RU', 'CA', 'PT', 'NG',
#        'IS', 'NO', 'HK', 'JO', 'KE', 'MT', 'VN', 'CH', 'NZ', 'FI', 'MX',
#        'TN', 'CO', 'AE', 'KR', 'DK', 'TZ', 'PH', 'GR', 'RO', 'CR', 'IL',
#        'SA', 'GH', 'PR', 'VE', 'LK', 'EG', 'MA', 'TH', 'AM', 'PG', 'CZ',
#        'SG', 'CL', 'YE', 'CY', 'PY', 'HR', 'MN', 'CM', 'UG', 'LT', 'EE',
#        'BH', 'DZ', 'IE', 'RS', 'KY', 'IR', 'GT', 'DO', 'PS', 'PE', 'BD',
#        'ET', 'SY', 'UY', 'RW', 'AS', 'PA', 'AL', 'UA', 'EC', 'KW', 'AD',
#        'NI', 'ZA', 'MM', 'FJ', 'LC', 'IQ', 'HT', 'AO', 'SD', 'SI', 'MK',
#        'OM', 'AQ', 'LY', 'AZ', 'AF', 'MO', 'BS', 'MZ', 'SV', 'ZM', 'LU',
#        'HN', 'BI', 'BJ', 'YT', 'GU', 'ML', 'BO', 'GW', 'TJ', 'KH', 'SR',
#        'LB', 'VU', 'AN', 'MP', 'MW', 'QA', 'MH', 'TM', 'UM', 'SZ', 'XK',
#        'NE', 'TT', 'SO', 'ZW', 'TK', 'BB', 'JM', 'NP', 'GI', 'KG', 'MG',
#        'FK', 'BY', 'MD', 'KZ', 'CU', 'GY', 'CD', 'CI', 'AW', 'SB', 'MV',
#        'UZ', 'VI', 'GM', 'BF', 'TG', 'ER', 'BT', 'CG', 'WS', 'TL', 'MU',
#        'NC', 'MQ', 'MR', 'LR', 'BM', 'BN', 'BW', 'MC', 'PF', 'WF', 'GL',
#        'PW', 'BA', 'FO', 'KN', 'SN', 'GD', 'GN', 'CK', 'GP', 'BV', 'SC',
#        'CV', 'GS', 'NF', 'BZ', 'VG', 'CS', 'RE', 'TF', 'VC', 'AI', 'SM',
#        'SH', 'SL', 'LI', 'GA', 'FM', 'TC', 'AG', 'LS', 'DM', 'KM', 'SS',
#        'GZ', 'EH', 'TO', 'KP', 'NU', 'ME', 'DJ', 'VA', 'TV', 'SJ', 'GF',
#        'PN', 'CX', 'IO', 'MS'], dtype=object)

# %%
#vediamo quanti valori mancanti sono presenti nella colonna di country_name:
lenders['country_code'].isnull().sum()
# Out:
# 1458635

# %%
#di questa serie di informazioni quelle che ci servono, sono il nome dei lenders ed il country_code, non avrebbe senso tenere tutto il dataset:
lenders_infoutili = lenders[['permanent_name', 'country_code']]
lenders_infoutili.head()
# Out:
#    permanent_name country_code
# 0        qian3013          NaN
# 1       reena6733          NaN
# 2         mai5982          NaN
# 3  andrew86079135          NaN
# 4      nguyen6962          NaN

# %%
#visto che per i dati mancanti devo sostituire cercando di impartire i dati mancanti seguendo la distribuzione di quelli noti:
#per prima cosa capisco la distribuzione di quelli noti volendo:
lenders_conteggio = lenders_infoutili.groupby('country_code').count().reset_index().rename(columns={'permanent_name':'conteggio_country'})
lenders_conteggio
# Out:
#     country_code  conteggio_country
# 0             AD                 15
# 1             AE               1043
# 2             AF                228
# 3             AG                  8
# 4             AI                  4
# ..           ...                ...
# 229           YE                195
# 230           YT                  2
# 231           ZA               1051
# 232           ZM                 65
# 233           ZW                 54
#
# [234 rows x 2 columns]

# %%
#calcolo il numero di lenders presenti come informazioni:
len(lenders)
# Out:
# 2349174

# %%
#trovo il numero di country segnate per i lenders
country_segnate = 2349174 - 1458635
country_segnate
# Out:
# 890539

# %%
lenders_conteggio['percentuale'] = lenders_conteggio['conteggio_country']/ country_segnate*100
lenders_conteggio
# Out:
#     country_code  conteggio_country  percentuale
# 0             AD                 15     0.001684
# 1             AE               1043     0.117120
# 2             AF                228     0.025602
# 3             AG                  8     0.000898
# 4             AI                  4     0.000449
# ..           ...                ...          ...
# 229           YE                195     0.021897
# 230           YT                  2     0.000225
# 231           ZA               1051     0.118018
# 232           ZM                 65     0.007299
# 233           ZW                 54     0.006064
#
# [234 rows x 3 columns]

# %%
lista_percentuale = lenders_conteggio['percentuale'].to_numpy()
codici_country = lenders_conteggio['country_code'].to_numpy()
lenders_conteggio['percentuale_unitaria'] = lenders_conteggio['percentuale'] / lenders_conteggio['percentuale'].sum()
lista_percentuale_unitaria = lenders_conteggio['percentuale_unitaria'].to_numpy()

# %%
lenders['country_code'] = lenders['country_code'].fillna(pd.Series(np.random.choice(codici_country, p= lista_percentuale_unitaria, size=len(lenders))))
lenders.head(20)
# Out:
#       permanent_name   display_name city state country_code  member_since  \
# 0           qian3013           Qian  NaN   NaN           US    1461300457
# 1          reena6733          Reena  NaN   NaN           US    1461300634
# 2            mai5982            Mai  NaN   NaN           GB    1461300853
# 3     andrew86079135         Andrew  NaN   NaN           US    1461301091
# 4         nguyen6962         Nguyen  NaN   NaN           CA    1461301154
# 5       sirinapa6764       Sirinapa  NaN   NaN           US    1461301496
# 6           rene7585           Rene  NaN   NaN           AU    1461301636
# 7         harald2826         Harald  NaN   NaN           US    1461301670
# 8          mehdi2903          Mehdi  NaN   NaN           AU    1461301756
# 9        youchan8125        Youchan  NaN   NaN           US    1461301941
# 10           zhu2998            Zhu  NaN   NaN           IT    1461302472
# 11      jennifer4328       Jennifer  NaN   NaN           US    1461302712
# 12     aniruddha9724      Aniruddha  NaN   NaN           US    1461302850
# 13  duraimurugan4891  Durai Murugan  NaN   NaN           US    1461302864
# 14         chuan7668          chuan  NaN   NaN           DK    1461302892
# 15         zhang2317          zhang  NaN   NaN           US    1461302899
# 16        naresh2074         Naresh  NaN   NaN           US    1461303119
# 17           min6557            Min  NaN   NaN           US    1461303121
# 18       weiting2757       Wei Ting  NaN   NaN           US    1461300705
# 19           you2163            you  NaN   NaN           US    1461300920
#
#    occupation loan_because  loan_purchase_num invited_by  num_invited
# 0         NaN          NaN                1.0        NaN            0
# 1         NaN          NaN                9.0        NaN            0
# 2         NaN          NaN                NaN        NaN            0
# 3         NaN          NaN                5.0  Peter Tan            0
# 4         NaN          NaN                NaN        NaN            0
# 5         NaN          NaN                1.0        NaN            0
# 6         NaN          NaN                2.0        NaN            0
# 7         NaN          NaN                2.0        NaN            0
# 8         NaN          NaN                NaN        NaN            0
# 9         NaN          NaN                1.0        NaN            0
# 10        NaN          NaN                1.0        NaN            0
# 11        NaN          NaN                3.0        NaN            0
# 12        NaN          NaN                1.0        NaN            0
# 13        NaN          NaN                1.0        NaN            1
# 14        NaN          NaN                NaN        NaN            0
# 15        NaN          NaN                NaN        NaN            0
# 16        NaN          NaN                3.0        NaN            0
# 17        NaN          NaN                2.0        NaN            0
# 18        NaN          NaN                1.0     Joanne            0
# 19        NaN          NaN                3.0        NaN            0

# %%
lenders_ammontare.head()
# Out:
#         lenders_y  amount_unitario
# 0             000      1456.996604
# 1           00000         0.000000
# 2            0002       677.081981
# 3        00mike00        52.631579
# 4  0101craign0101       606.748996

# %%
lenders_semi = pd.merge(lenders, lenders_ammontare, left_on = 'permanent_name', right_on = 'lenders_y')
lenders_semi.head()
# Out:
#    permanent_name display_name city state country_code  member_since  \
# 0        qian3013         Qian  NaN   NaN           US    1461300457
# 1       reena6733        Reena  NaN   NaN           US    1461300634
# 2  andrew86079135       Andrew  NaN   NaN           US    1461301091
# 3    sirinapa6764     Sirinapa  NaN   NaN           US    1461301496
# 4        rene7585         Rene  NaN   NaN           AU    1461301636
#
#   occupation loan_because  loan_purchase_num invited_by  num_invited  \
# 0        NaN          NaN                1.0        NaN            0
# 1        NaN          NaN                9.0        NaN            0
# 2        NaN          NaN                5.0  Peter Tan            0
# 3        NaN          NaN                1.0        NaN            0
# 4        NaN          NaN                2.0        NaN            0
#
#         lenders_y  amount_unitario
# 0        qian3013        46.839080
# 1       reena6733       417.948366
# 2  andrew86079135       349.601088
# 3    sirinapa6764        50.000000
# 4        rene7585        59.126984

# %%
#ora che i vari lenders per ogni stato, non mi resta che raggruppare gli stati in modo tale da ottenere la somma di ogni ammontare devoluto da ogni stato:
lenders_semi_denaro = round(lenders_semi.groupby('country_code')['amount_unitario'].sum(),0)
lenders_semi_denaro.head(20)
# Out:
# country_code
# AD        3843.0
# AE     1586484.0
# AF       92778.0
# AG        1885.0
# AI         398.0
# AL       15030.0
# AM       25868.0
# AN       32147.0
# AO       35430.0
# AQ       14749.0
# AR      975770.0
# AS       13356.0
# AT     2334261.0
# AU    48243806.0
# AW        7610.0
# AZ       11201.0
# BA       56553.0
# BB       14212.0
# BD       67724.0
# BE     2618041.0
# Name: amount_unitario, dtype: float64

# %%
loans_amount.head(20)
# Out:
# country_code
# AF       14000.0
# AL     4307350.0
# AM    20579275.0
# AZ     6839400.0
# BF     3990450.0
# BI     4476075.0
# BJ     2132125.0
# BO    31839450.0
# BR     1192325.0
# BT       20000.0
# BW        8000.0
# BZ      150175.0
# CA       50000.0
# CD    16363725.0
# CG     1943625.0
# CI      119425.0
# CL     1691650.0
# CM     1815825.0
# CN      380525.0
# CO    21614250.0
# Name: loan_amount, dtype: float64

# %%
denaro_differenza = lenders_semi_denaro - loans_amount
differenza_nomissing = denaro_differenza.dropna()
differenza_nomissing
differenza_nomissing.head(20)
# Out:
# country_code
# AF       78778.0
# AL    -4292320.0
# AM   -20553407.0
# AZ    -6828199.0
# BF    -3987426.0
# BI    -4474637.0
# BJ    -2129924.0
# BO   -31810030.0
# BR      706996.0
# BT      -18667.0
# BW        4425.0
# BZ     -130259.0
# CA    67251143.0
# CD   -16356017.0
# CG    -1940212.0
# CI     -100415.0
# CL    -1414286.0
# CM    -1798125.0
# CN      661625.0
# CO   -21310123.0
# dtype: float64

# %%
differenza = {"differenza_nomissing": differenza_nomissing}
differenza_tabella = pd.DataFrame(differenza)
differenza_tabella.reset_index()
# Out:
#    country_code  differenza_nomissing
# 0            AF               78778.0
# 1            AL            -4292320.0
# 2            AM           -20553407.0
# 3            AZ            -6828199.0
# 4            BF            -3987426.0
# ..          ...                   ...
# 84           XK            -3076616.0
# 85           YE            -3386918.0
# 86           ZA             -315716.0
# 87           ZM            -1934919.0
# 88           ZW            -4904010.0
#
# [89 rows x 2 columns]

# %%
#Punto 10
#Which country has the highest ratio between the difference computed at the previous point and the population?

# %%
statistiche_country = pd.read_csv('/Users/matteo/Downloads/country_stats.csv')
statistiche_country.head()
# Out:
#   country_name country_code country_code3 continent           region  \
# 0        India           IN           IND      Asia    Southern Asia
# 1      Nigeria           NG           NGA    Africa   Western Africa
# 2       Mexico           MX           MEX  Americas  Central America
# 3     Pakistan           PK           PAK      Asia    Southern Asia
# 4   Bangladesh           BD           BGD      Asia    Southern Asia
#
#    population  population_below_poverty_line       hdi  life_expectancy  \
# 0  1339180127                           21.9  0.623559           68.322
# 1   190886311                           70.0  0.527105           53.057
# 2   129163276                           46.2  0.761683           76.972
# 3   197015955                           29.5  0.550354           66.365
# 4   164669751                           31.5  0.578824           71.985
#
#    expected_years_of_schooling  mean_years_of_schooling           gni  \
# 0                    11.696590                 6.298834   5663.474799
# 1                     9.970482                 6.000000   5442.901264
# 2                    13.299090                 8.554985  16383.106680
# 3                     8.106910                 5.089460   5031.173074
# 4                    10.178706                 5.241577   3341.490722
#
#   kiva_country_name
# 0             India
# 1           Nigeria
# 2            Mexico
# 3          Pakistan
# 4        Bangladesh

# %%
#uniamo i datasets:
statistiche_unite = pd.merge(statistiche_country, differenza_tabella, left_on = 'country_code', right_on = 'country_code')
statistiche_unite.head(10)
# Out:
#                        country_name country_code country_code3 continent  \
# 0                             India           IN           IND      Asia
# 1                           Nigeria           NG           NGA    Africa
# 2                            Mexico           MX           MEX  Americas
# 3                          Pakistan           PK           PAK      Asia
# 4  Democratic Republic of the Congo           CD           COD    Africa
# 5                     United States           US           USA  Americas
# 6                             China           CN           CHN      Asia
# 7                         Indonesia           ID           IDN      Asia
# 8                             Egypt           EG           EGY    Africa
# 9                       Philippines           PH           PHL      Asia
#
#                region  population  population_below_poverty_line       hdi  \
# 0       Southern Asia  1339180127                           21.9  0.623559
# 1      Western Africa   190886311                           70.0  0.527105
# 2     Central America   129163276                           46.2  0.761683
# 3       Southern Asia   197015955                           29.5  0.550354
# 4       Middle Africa    81339988                           63.0  0.435465
# 5    Northern America   324459463                           15.1  0.919553
# 6        Eastern Asia  1409517397                            3.3  0.737681
# 7  South-eastern Asia   263991379                           10.9  0.688847
# 8     Northern Africa    97553151                           25.2  0.691392
# 9  South-eastern Asia   104918090                           21.6  0.681799
#
#    life_expectancy  expected_years_of_schooling  mean_years_of_schooling  \
# 0           68.322                    11.696590                 6.298834
# 1           53.057                     9.970482                 6.000000
# 2           76.972                    13.299090                 8.554985
# 3           66.365                     8.106910                 5.089460
# 4           59.057                     9.750000                 6.117153
# 5           79.222                    16.538150                13.217890
# 6           75.963                    13.535750                 7.641840
# 7           69.052                    12.867660                 7.934817
# 8           71.325                    13.098900                 7.110000
# 9           68.340                    11.733020                 9.326870
#
#             gni                     kiva_country_name  differenza_nomissing
# 0   5663.474799                                 India            -6719890.0
# 1   5442.901264                               Nigeria            -2393293.0
# 2  16383.106680                                Mexico           -14535623.0
# 3   5031.173074                              Pakistan           -19672516.0
# 4    679.631223  The Democratic Republic of the Congo           -16356017.0
# 5  53245.076960                         United States           504685184.0
# 6  13345.477460                                 China              661625.0
# 7  10053.337700                             Indonesia            -5641921.0
# 8  10064.059910                                 Egypt            -1161687.0
# 9   8395.094758                           Philippines           -80550021.0

# %%
statistiche_unite['differenza_popolazione'] = statistiche_unite['differenza_nomissing'] / statistiche_unite['population']
statistiche_unite.head(10)
# Out:
#                        country_name country_code country_code3 continent  \
# 0                             India           IN           IND      Asia
# 1                           Nigeria           NG           NGA    Africa
# 2                            Mexico           MX           MEX  Americas
# 3                          Pakistan           PK           PAK      Asia
# 4  Democratic Republic of the Congo           CD           COD    Africa
# 5                     United States           US           USA  Americas
# 6                             China           CN           CHN      Asia
# 7                         Indonesia           ID           IDN      Asia
# 8                             Egypt           EG           EGY    Africa
# 9                       Philippines           PH           PHL      Asia
#
#                region  population  population_below_poverty_line       hdi  \
# 0       Southern Asia  1339180127                           21.9  0.623559
# 1      Western Africa   190886311                           70.0  0.527105
# 2     Central America   129163276                           46.2  0.761683
# 3       Southern Asia   197015955                           29.5  0.550354
# 4       Middle Africa    81339988                           63.0  0.435465
# 5    Northern America   324459463                           15.1  0.919553
# 6        Eastern Asia  1409517397                            3.3  0.737681
# 7  South-eastern Asia   263991379                           10.9  0.688847
# 8     Northern Africa    97553151                           25.2  0.691392
# 9  South-eastern Asia   104918090                           21.6  0.681799
#
#    life_expectancy  expected_years_of_schooling  mean_years_of_schooling  \
# 0           68.322                    11.696590                 6.298834
# 1           53.057                     9.970482                 6.000000
# 2           76.972                    13.299090                 8.554985
# 3           66.365                     8.106910                 5.089460
# 4           59.057                     9.750000                 6.117153
# 5           79.222                    16.538150                13.217890
# 6           75.963                    13.535750                 7.641840
# 7           69.052                    12.867660                 7.934817
# 8           71.325                    13.098900                 7.110000
# 9           68.340                    11.733020                 9.326870
#
#             gni                     kiva_country_name  differenza_nomissing  \
# 0   5663.474799                                 India            -6719890.0
# 1   5442.901264                               Nigeria            -2393293.0
# 2  16383.106680                                Mexico           -14535623.0
# 3   5031.173074                              Pakistan           -19672516.0
# 4    679.631223  The Democratic Republic of the Congo           -16356017.0
# 5  53245.076960                         United States           504685184.0
# 6  13345.477460                                 China              661625.0
# 7  10053.337700                             Indonesia            -5641921.0
# 8  10064.059910                                 Egypt            -1161687.0
# 9   8395.094758                           Philippines           -80550021.0
#
#    differenza_popolazione
# 0               -0.005018
# 1               -0.012538
# 2               -0.112537
# 3               -0.099852
# 4               -0.201082
# 5                1.555465
# 6                0.000469
# 7               -0.021372
# 8               -0.011908
# 9               -0.767742

# %%
statistiche_unite[statistiche_unite['differenza_popolazione']==statistiche_unite['differenza_popolazione'].max()]
# Out:
#    country_name country_code country_code3 continent            region  \
# 47       Canada           CA           CAN  Americas  Northern America
#
#     population  population_below_poverty_line       hdi  life_expectancy  \
# 47    36624199                            9.4  0.920284           82.224
#
#     expected_years_of_schooling  mean_years_of_schooling          gni  \
# 47                       16.325                13.105115  42581.91433
#
#    kiva_country_name  differenza_nomissing  differenza_popolazione
# 47            Canada            67251143.0                1.836249

# %%
#Punto 11
statistiche_unite.head()
# Out:
#                        country_name country_code country_code3 continent  \
# 0                             India           IN           IND      Asia
# 1                           Nigeria           NG           NGA    Africa
# 2                            Mexico           MX           MEX  Americas
# 3                          Pakistan           PK           PAK      Asia
# 4  Democratic Republic of the Congo           CD           COD    Africa
#
#             region  population  population_below_poverty_line       hdi  \
# 0    Southern Asia  1339180127                           21.9  0.623559
# 1   Western Africa   190886311                           70.0  0.527105
# 2  Central America   129163276                           46.2  0.761683
# 3    Southern Asia   197015955                           29.5  0.550354
# 4    Middle Africa    81339988                           63.0  0.435465
#
#    life_expectancy  expected_years_of_schooling  mean_years_of_schooling  \
# 0           68.322                    11.696590                 6.298834
# 1           53.057                     9.970482                 6.000000
# 2           76.972                    13.299090                 8.554985
# 3           66.365                     8.106910                 5.089460
# 4           59.057                     9.750000                 6.117153
#
#             gni                     kiva_country_name  differenza_nomissing  \
# 0   5663.474799                                 India            -6719890.0
# 1   5442.901264                               Nigeria            -2393293.0
# 2  16383.106680                                Mexico           -14535623.0
# 3   5031.173074                              Pakistan           -19672516.0
# 4    679.631223  The Democratic Republic of the Congo           -16356017.0
#
#    differenza_popolazione
# 0               -0.005018
# 1               -0.012538
# 2               -0.112537
# 3               -0.099852
# 4               -0.201082

# %%
statistiche_unite['popolazione_sotto_soglia'] = (statistiche_unite['population'] * statistiche_unite['population_below_poverty_line']) / 100
statistiche_unite.head()
# Out:
#                        country_name country_code country_code3 continent  \
# 0                             India           IN           IND      Asia
# 1                           Nigeria           NG           NGA    Africa
# 2                            Mexico           MX           MEX  Americas
# 3                          Pakistan           PK           PAK      Asia
# 4  Democratic Republic of the Congo           CD           COD    Africa
#
#             region  population  population_below_poverty_line       hdi  \
# 0    Southern Asia  1339180127                           21.9  0.623559
# 1   Western Africa   190886311                           70.0  0.527105
# 2  Central America   129163276                           46.2  0.761683
# 3    Southern Asia   197015955                           29.5  0.550354
# 4    Middle Africa    81339988                           63.0  0.435465
#
#    life_expectancy  expected_years_of_schooling  mean_years_of_schooling  \
# 0           68.322                    11.696590                 6.298834
# 1           53.057                     9.970482                 6.000000
# 2           76.972                    13.299090                 8.554985
# 3           66.365                     8.106910                 5.089460
# 4           59.057                     9.750000                 6.117153
#
#             gni                     kiva_country_name  differenza_nomissing  \
# 0   5663.474799                                 India            -6719890.0
# 1   5442.901264                               Nigeria            -2393293.0
# 2  16383.106680                                Mexico           -14535623.0
# 3   5031.173074                              Pakistan           -19672516.0
# 4    679.631223  The Democratic Republic of the Congo           -16356017.0
#
#    differenza_popolazione  popolazione_sotto_soglia
# 0               -0.005018              2.932804e+08
# 1               -0.012538              1.336204e+08
# 2               -0.112537              5.967343e+07
# 3               -0.099852              5.811971e+07
# 4               -0.201082              5.124419e+07

# %%
statistiche_unite['popolazione_sopra_soglia'] = statistiche_unite['population'] - statistiche_unite['popolazione_sotto_soglia']
statistiche_unite.head()
# Out:
#                        country_name country_code country_code3 continent  \
# 0                             India           IN           IND      Asia
# 1                           Nigeria           NG           NGA    Africa
# 2                            Mexico           MX           MEX  Americas
# 3                          Pakistan           PK           PAK      Asia
# 4  Democratic Republic of the Congo           CD           COD    Africa
#
#             region  population  population_below_poverty_line       hdi  \
# 0    Southern Asia  1339180127                           21.9  0.623559
# 1   Western Africa   190886311                           70.0  0.527105
# 2  Central America   129163276                           46.2  0.761683
# 3    Southern Asia   197015955                           29.5  0.550354
# 4    Middle Africa    81339988                           63.0  0.435465
#
#    life_expectancy  expected_years_of_schooling  mean_years_of_schooling  \
# 0           68.322                    11.696590                 6.298834
# 1           53.057                     9.970482                 6.000000
# 2           76.972                    13.299090                 8.554985
# 3           66.365                     8.106910                 5.089460
# 4           59.057                     9.750000                 6.117153
#
#             gni                     kiva_country_name  differenza_nomissing  \
# 0   5663.474799                                 India            -6719890.0
# 1   5442.901264                               Nigeria            -2393293.0
# 2  16383.106680                                Mexico           -14535623.0
# 3   5031.173074                              Pakistan           -19672516.0
# 4    679.631223  The Democratic Republic of the Congo           -16356017.0
#
#    differenza_popolazione  popolazione_sotto_soglia  popolazione_sopra_soglia
# 0               -0.005018              2.932804e+08              1.045900e+09
# 1               -0.012538              1.336204e+08              5.726589e+07
# 2               -0.112537              5.967343e+07              6.948984e+07
# 3               -0.099852              5.811971e+07              1.388962e+08
# 4               -0.201082              5.124419e+07              3.009580e+07

# %%
statistiche_unite['differenza_povertà'] = statistiche_unite['differenza_popolazione'] / statistiche_unite['popolazione_sopra_soglia']
statistiche_unite.head()
# Out:
#                        country_name country_code country_code3 continent  \
# 0                             India           IN           IND      Asia
# 1                           Nigeria           NG           NGA    Africa
# 2                            Mexico           MX           MEX  Americas
# 3                          Pakistan           PK           PAK      Asia
# 4  Democratic Republic of the Congo           CD           COD    Africa
#
#             region  population  population_below_poverty_line       hdi  \
# 0    Southern Asia  1339180127                           21.9  0.623559
# 1   Western Africa   190886311                           70.0  0.527105
# 2  Central America   129163276                           46.2  0.761683
# 3    Southern Asia   197015955                           29.5  0.550354
# 4    Middle Africa    81339988                           63.0  0.435465
#
#    life_expectancy  expected_years_of_schooling  mean_years_of_schooling  \
# 0           68.322                    11.696590                 6.298834
# 1           53.057                     9.970482                 6.000000
# 2           76.972                    13.299090                 8.554985
# 3           66.365                     8.106910                 5.089460
# 4           59.057                     9.750000                 6.117153
#
#             gni                     kiva_country_name  differenza_nomissing  \
# 0   5663.474799                                 India            -6719890.0
# 1   5442.901264                               Nigeria            -2393293.0
# 2  16383.106680                                Mexico           -14535623.0
# 3   5031.173074                              Pakistan           -19672516.0
# 4    679.631223  The Democratic Republic of the Congo           -16356017.0
#
#    differenza_popolazione  popolazione_sotto_soglia  popolazione_sopra_soglia  \
# 0               -0.005018              2.932804e+08              1.045900e+09
# 1               -0.012538              1.336204e+08              5.726589e+07
# 2               -0.112537              5.967343e+07              6.948984e+07
# 3               -0.099852              5.811971e+07              1.388962e+08
# 4               -0.201082              5.124419e+07              3.009580e+07
#
#    differenza_povertà
# 0       -4.797701e-12
# 1       -2.189400e-10
# 2       -1.619471e-09
# 3       -7.188992e-10
# 4       -6.681402e-09

# %%
max_povertà = statistiche_unite['differenza_povertà'].max()
statistiche_unite[statistiche_unite['differenza_povertà'] == max_povertà]
# Out:
#    country_name country_code country_code3 continent            region  \
# 47       Canada           CA           CAN  Americas  Northern America
#
#     population  population_below_poverty_line       hdi  life_expectancy  \
# 47    36624199                            9.4  0.920284           82.224
#
#     expected_years_of_schooling  mean_years_of_schooling          gni  \
# 47                       16.325                13.105115  42581.91433
#
#    kiva_country_name  differenza_nomissing  differenza_popolazione  \
# 47            Canada            67251143.0                1.836249
#
#     popolazione_sotto_soglia  popolazione_sopra_soglia  differenza_povertà
# 47               3442674.706              3.318152e+07        5.533950e-08

# %%
#Punto 12
#For each year, compute the total amount of loans. Each loan that has planned expiration time and disburse time in different years must have its amount distributed proportionally to the number of days in each year. For example, a loan with disburse time December 1st, 2016, planned expiration time January 30th 2018, and amount 5000USD has an amount of 5000USD * 31 / (31+365+30) = 363.85 for 2016, 5000USD * 365 / (31+365+30) = 4284.04 for 2017, and 5000USD * 30 / (31+365+30) = 352.11 for 2018.

# %%
loans.head()
# Out:
#    loan_id       loan_name original_language  \
# 0   657307            Aivy           English
# 1   657259  Idalia Marizza           Spanish
# 2   658010           Aasia           English
# 3   659347         Gulmira           Russian
# 4   656933         Ricky\t           English
#
#                                          description  \
# 0  Aivy, 21 years of age, is single and lives in ...
# 1  Doña Idalia, esta casada, tiene 57 años de eda...
# 2  Aasia is a 45-year-old married lady and she ha...
# 3  Гулмире 36 лет, замужем, вместе с супругом вос...
# 4  Ricky is a farmer who currently cultivates his...
#
#                               description_translated  funded_amount  \
# 0                                                NaN          125.0
# 1  Idalia, 57, is married and lives with her husb...          400.0
# 2                                                NaN          400.0
# 3  Gulmira is 36 years old and married.  She and ...          625.0
# 4                                                NaN          425.0
#
#    loan_amount  status  activity_name  sector_name  ... num_journal_entries  \
# 0        125.0  funded  General Store       Retail  ...                   2
# 1        400.0  funded  Used Clothing     Clothing  ...                   2
# 2        400.0  funded  General Store       Retail  ...                   2
# 3        625.0  funded        Farming  Agriculture  ...                   2
# 4        425.0  funded        Farming  Agriculture  ...                   2
#
#   num_bulk_entries                                               tags  \
# 0                1                                                NaN
# 1                1                                                NaN
# 2                1  #Woman Owned Biz, #Supporting Family, user_fav...
# 3                1                                      user_favorite
# 4                1           #Animals, #Eco-friendly, #Sustainable Ag
#
#   borrower_genders borrower_pictured  repayment_interval distribution_model  \
# 0           female              true           irregular      field_partner
# 1           female              true             monthly      field_partner
# 2           female              true             monthly      field_partner
# 3           female              true             monthly      field_partner
# 4             male              true              bullet      field_partner
#
#          disburse_time_date planned_expiration_time_date         duration
# 0 2013-12-22 08:00:00+00:00    2014-02-14 03:30:06+00:00 53 days 19:30:06
# 1 2013-12-20 08:00:00+00:00    2014-03-26 22:25:07+00:00 96 days 14:25:07
# 2 2014-01-09 08:00:00+00:00    2014-02-15 21:10:05+00:00 37 days 13:10:05
# 3 2014-01-17 08:00:00+00:00    2014-02-21 03:10:02+00:00 34 days 19:10:02
# 4 2013-12-17 08:00:00+00:00    2014-02-13 06:10:02+00:00 57 days 22:10:02
#
# [5 rows x 34 columns]

# %%
loans_utili = loans[['loan_id', 'disburse_time_date', 'planned_expiration_time_date', 'loan_amount']]
loans_utili.head()
# Out:
#    loan_id        disburse_time_date planned_expiration_time_date  loan_amount
# 0   657307 2013-12-22 08:00:00+00:00    2014-02-14 03:30:06+00:00        125.0
# 1   657259 2013-12-20 08:00:00+00:00    2014-03-26 22:25:07+00:00        400.0
# 2   658010 2014-01-09 08:00:00+00:00    2014-02-15 21:10:05+00:00        400.0
# 3   659347 2014-01-17 08:00:00+00:00    2014-02-21 03:10:02+00:00        625.0
# 4   656933 2013-12-17 08:00:00+00:00    2014-02-13 06:10:02+00:00        425.0

# %%
#come visto in precedenza, sono presenti dei dati mancanti:
loans_utili.isnull().sum()
# Out:
# loan_id                              0
# disburse_time_date                2813
# planned_expiration_time_date    371834
# loan_amount                          0
# dtype: int64

# %%
#procediamo con l'eliminare i dati mancanti:
loans_utili_no_missing = loans_utili.dropna()

# %%
#controlliamo che effettivamente non siano presenti dati mancanti:
loans_utili_no_missing.isnull().sum()
# Out:
# loan_id                         0
# disburse_time_date              0
# planned_expiration_time_date    0
# loan_amount                     0
# dtype: int64

# %%
loans_utili_no_missing["disburse_time_date"].dt.tz_localize(None)
loans_utili_no_missing["planned_expiration_time_date"].dt.tz_localize(None)
# Out:
# 0         2014-02-14 03:30:06
# 1         2014-03-26 22:25:07
# 2         2014-02-15 21:10:05
# 3         2014-02-21 03:10:02
# 4         2014-02-13 06:10:02
#                   ...
# 1419602   2016-01-02 01:00:03
# 1419603   2016-01-02 16:40:07
# 1419604   2016-01-03 22:20:04
# 1419605   2016-01-05 08:50:02
# 1419606   2016-01-03 20:50:06
# Name: planned_expiration_time_date, Length: 1044962, dtype: datetime64[ns]

# %%
loans_utili_no_missing["disburse_year"] = loans_utili_no_missing["disburse_time_date"].dt.year
loans_utili_no_missing["planned_expiration_year"] = loans_utili_no_missing["planned_expiration_time_date"].dt.year
loans_utili_no_missing['differenza_anni'] = loans_utili_no_missing['planned_expiration_year'] - loans_utili_no_missing['disburse_year']
loans_utili_no_missing.head()
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#    loan_id        disburse_time_date planned_expiration_time_date  \
# 0   657307 2013-12-22 08:00:00+00:00    2014-02-14 03:30:06+00:00
# 1   657259 2013-12-20 08:00:00+00:00    2014-03-26 22:25:07+00:00
# 2   658010 2014-01-09 08:00:00+00:00    2014-02-15 21:10:05+00:00
# 3   659347 2014-01-17 08:00:00+00:00    2014-02-21 03:10:02+00:00
# 4   656933 2013-12-17 08:00:00+00:00    2014-02-13 06:10:02+00:00
#
#    loan_amount  disburse_year  planned_expiration_year  differenza_anni
# 0        125.0           2013                     2014                1
# 1        400.0           2013                     2014                1
# 2        400.0           2014                     2014                0
# 3        625.0           2014                     2014                0
# 4        425.0           2013                     2014                1

# %%
loans_nodifferenzaanni = loans_utili_no_missing[loans_utili_no_missing['differenza_anni'] == 0]
loans_nodifferenzaanni.head()
# Out:
#    loan_id        disburse_time_date planned_expiration_time_date  \
# 2   658010 2014-01-09 08:00:00+00:00    2014-02-15 21:10:05+00:00
# 3   659347 2014-01-17 08:00:00+00:00    2014-02-21 03:10:02+00:00
# 5   659605 2014-01-15 08:00:00+00:00    2014-02-20 02:30:07+00:00
# 6   660240 2014-01-20 08:00:00+00:00    2014-02-21 07:50:11+00:00
# 7   661601 2014-01-10 08:00:00+00:00    2014-02-25 09:50:03+00:00
#
#    loan_amount  disburse_year  planned_expiration_year  differenza_anni
# 2        400.0           2014                     2014                0
# 3        625.0           2014                     2014                0
# 5        350.0           2014                     2014                0
# 6        125.0           2014                     2014                0
# 7       1600.0           2014                     2014                0

# %%
loans_differenzaanni = loans_utili_no_missing[loans_utili_no_missing['differenza_anni'] != 0]
loans_differenzaanni.head()
# Out:
#     loan_id        disburse_time_date planned_expiration_time_date  \
# 0    657307 2013-12-22 08:00:00+00:00    2014-02-14 03:30:06+00:00
# 1    657259 2013-12-20 08:00:00+00:00    2014-03-26 22:25:07+00:00
# 4    656933 2013-12-17 08:00:00+00:00    2014-02-13 06:10:02+00:00
# 12   660363 2013-12-23 08:00:00+00:00    2014-02-21 17:10:02+00:00
# 13   661165 2013-12-26 08:00:00+00:00    2014-03-26 22:24:34+00:00
#
#     loan_amount  disburse_year  planned_expiration_year  differenza_anni
# 0         125.0           2013                     2014                1
# 1         400.0           2013                     2014                1
# 4         425.0           2013                     2014                1
# 12       1175.0           2013                     2014                1
# 13        300.0           2013                     2014                1

# %%
#Gli anni quindi so che vanno dal 2011 al 2018, si tratta di un range di 7 anni di prestiti:
print(loans_utili_no_missing['disburse_year'].min(), loans_utili_no_missing['disburse_year'].max(), loans_utili_no_missing['planned_expiration_year'].min(), loans_utili_no_missing['planned_expiration_year'].max())
# Out:
# 2011 2018 2012 2018

# %%
#Realizzando un dataframe che contiene tutti gli anni, poi successivamente raggruppando tutti gli anni, posso trovare la somma per ogni anno del totale dei loans:
prestiti_anno = pd.DataFrame(0, index = [0], columns = ["2011", "2012", "2013", "2014", "2015", "2016", "2017", "2018"])
prestiti_anno.head()
# Out:
#    2011  2012  2013  2014  2015  2016  2017  2018
# 0     0     0     0     0     0     0     0     0

# %%
from pandas.tseries import offsets
loans_differenzaanni['fine_anno'] = loans_differenzaanni.disburse_time_date.apply(lambda i : i + pd.offsets.YearEnd())
loans_differenzaanni.head(10)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#     loan_id        disburse_time_date planned_expiration_time_date  \
# 0    657307 2013-12-22 08:00:00+00:00    2014-02-14 03:30:06+00:00
# 1    657259 2013-12-20 08:00:00+00:00    2014-03-26 22:25:07+00:00
# 4    656933 2013-12-17 08:00:00+00:00    2014-02-13 06:10:02+00:00
# 12   660363 2013-12-23 08:00:00+00:00    2014-02-21 17:10:02+00:00
# 13   661165 2013-12-26 08:00:00+00:00    2014-03-26 22:24:34+00:00
# 71   808452 2014-11-06 08:00:00+00:00    2015-01-18 17:50:04+00:00
# 74  1204329 2016-11-18 08:00:00+00:00    2017-01-14 14:20:02+00:00
# 75  1212312 2016-12-07 08:00:00+00:00    2017-01-28 03:20:03+00:00
# 79   659111 2013-12-19 08:00:00+00:00    2014-02-19 16:50:02+00:00
# 82   661912 2013-12-28 08:00:00+00:00    2014-02-25 13:20:04+00:00
#
#     loan_amount  disburse_year  planned_expiration_year  differenza_anni  \
# 0         125.0           2013                     2014                1
# 1         400.0           2013                     2014                1
# 4         425.0           2013                     2014                1
# 12       1175.0           2013                     2014                1
# 13        300.0           2013                     2014                1
# 71        225.0           2014                     2015                1
# 74        725.0           2016                     2017                1
# 75       3750.0           2016                     2017                1
# 79        875.0           2013                     2014                1
# 82        625.0           2013                     2014                1
#
#                    fine_anno               inizio_anno  \
# 0  2013-12-31 08:00:00+00:00 2014-01-01 03:30:06+00:00
# 1  2013-12-31 08:00:00+00:00 2014-01-01 22:25:07+00:00
# 4  2013-12-31 08:00:00+00:00 2014-01-01 06:10:02+00:00
# 12 2013-12-31 08:00:00+00:00 2014-01-01 17:10:02+00:00
# 13 2013-12-31 08:00:00+00:00 2014-01-01 22:24:34+00:00
# 71 2014-12-31 08:00:00+00:00 2015-01-01 17:50:04+00:00
# 74 2016-12-31 08:00:00+00:00 2017-01-01 14:20:02+00:00
# 75 2016-12-31 08:00:00+00:00 2017-01-01 03:20:03+00:00
# 79 2013-12-31 08:00:00+00:00 2014-01-01 16:50:02+00:00
# 82 2013-12-31 08:00:00+00:00 2014-01-01 13:20:04+00:00
#
#     differenza_giorni_inizio  giorni_differenza_totale  \
# 0                         44                        53
# 1                         84                        96
# 4                         43                        57
# 12                        51                        60
# 13                        84                        90
# 71                        17                        73
# 74                        13                        57
# 75                        27                        51
# 79                        49                        62
# 82                        55                        59
#
#     differenza_giorni_alla_fine
# 0                             9
# 1                            11
# 4                            14
# 12                            8
# 13                            5
# 71                           55
# 74                           43
# 75                           24
# 79                           12
# 82                            3

# %%
#Ora devo vedere quale sarebbe il primo giorno rispetto 
loans_differenzaanni['inizio_anno'] = loans_differenzaanni.planned_expiration_time_date.apply(lambda i : i - pd.offsets.YearBegin())
loans_differenzaanni.head(10)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#     loan_id        disburse_time_date planned_expiration_time_date  \
# 0    657307 2013-12-22 08:00:00+00:00    2014-02-14 03:30:06+00:00
# 1    657259 2013-12-20 08:00:00+00:00    2014-03-26 22:25:07+00:00
# 4    656933 2013-12-17 08:00:00+00:00    2014-02-13 06:10:02+00:00
# 12   660363 2013-12-23 08:00:00+00:00    2014-02-21 17:10:02+00:00
# 13   661165 2013-12-26 08:00:00+00:00    2014-03-26 22:24:34+00:00
# 71   808452 2014-11-06 08:00:00+00:00    2015-01-18 17:50:04+00:00
# 74  1204329 2016-11-18 08:00:00+00:00    2017-01-14 14:20:02+00:00
# 75  1212312 2016-12-07 08:00:00+00:00    2017-01-28 03:20:03+00:00
# 79   659111 2013-12-19 08:00:00+00:00    2014-02-19 16:50:02+00:00
# 82   661912 2013-12-28 08:00:00+00:00    2014-02-25 13:20:04+00:00
#
#     loan_amount  disburse_year  planned_expiration_year  differenza_anni  \
# 0         125.0           2013                     2014                1
# 1         400.0           2013                     2014                1
# 4         425.0           2013                     2014                1
# 12       1175.0           2013                     2014                1
# 13        300.0           2013                     2014                1
# 71        225.0           2014                     2015                1
# 74        725.0           2016                     2017                1
# 75       3750.0           2016                     2017                1
# 79        875.0           2013                     2014                1
# 82        625.0           2013                     2014                1
#
#                    fine_anno               inizio_anno
# 0  2013-12-31 08:00:00+00:00 2014-01-01 03:30:06+00:00
# 1  2013-12-31 08:00:00+00:00 2014-01-01 22:25:07+00:00
# 4  2013-12-31 08:00:00+00:00 2014-01-01 06:10:02+00:00
# 12 2013-12-31 08:00:00+00:00 2014-01-01 17:10:02+00:00
# 13 2013-12-31 08:00:00+00:00 2014-01-01 22:24:34+00:00
# 71 2014-12-31 08:00:00+00:00 2015-01-01 17:50:04+00:00
# 74 2016-12-31 08:00:00+00:00 2017-01-01 14:20:02+00:00
# 75 2016-12-31 08:00:00+00:00 2017-01-01 03:20:03+00:00
# 79 2013-12-31 08:00:00+00:00 2014-01-01 16:50:02+00:00
# 82 2013-12-31 08:00:00+00:00 2014-01-01 13:20:04+00:00

# %%
loans_differenzaanni['differenza_giorni_alla_fine'] = (loans_differenzaanni['fine_anno'] - loans_differenzaanni['disburse_time_date']).dt.days
loans_differenzaanni.head(10)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#     loan_id        disburse_time_date planned_expiration_time_date  \
# 0    657307 2013-12-22 08:00:00+00:00    2014-02-14 03:30:06+00:00
# 1    657259 2013-12-20 08:00:00+00:00    2014-03-26 22:25:07+00:00
# 4    656933 2013-12-17 08:00:00+00:00    2014-02-13 06:10:02+00:00
# 12   660363 2013-12-23 08:00:00+00:00    2014-02-21 17:10:02+00:00
# 13   661165 2013-12-26 08:00:00+00:00    2014-03-26 22:24:34+00:00
# 71   808452 2014-11-06 08:00:00+00:00    2015-01-18 17:50:04+00:00
# 74  1204329 2016-11-18 08:00:00+00:00    2017-01-14 14:20:02+00:00
# 75  1212312 2016-12-07 08:00:00+00:00    2017-01-28 03:20:03+00:00
# 79   659111 2013-12-19 08:00:00+00:00    2014-02-19 16:50:02+00:00
# 82   661912 2013-12-28 08:00:00+00:00    2014-02-25 13:20:04+00:00
#
#     loan_amount  disburse_year  planned_expiration_year  differenza_anni  \
# 0         125.0           2013                     2014                1
# 1         400.0           2013                     2014                1
# 4         425.0           2013                     2014                1
# 12       1175.0           2013                     2014                1
# 13        300.0           2013                     2014                1
# 71        225.0           2014                     2015                1
# 74        725.0           2016                     2017                1
# 75       3750.0           2016                     2017                1
# 79        875.0           2013                     2014                1
# 82        625.0           2013                     2014                1
#
#                    fine_anno               inizio_anno  \
# 0  2013-12-31 08:00:00+00:00 2014-01-01 03:30:06+00:00
# 1  2013-12-31 08:00:00+00:00 2014-01-01 22:25:07+00:00
# 4  2013-12-31 08:00:00+00:00 2014-01-01 06:10:02+00:00
# 12 2013-12-31 08:00:00+00:00 2014-01-01 17:10:02+00:00
# 13 2013-12-31 08:00:00+00:00 2014-01-01 22:24:34+00:00
# 71 2014-12-31 08:00:00+00:00 2015-01-01 17:50:04+00:00
# 74 2016-12-31 08:00:00+00:00 2017-01-01 14:20:02+00:00
# 75 2016-12-31 08:00:00+00:00 2017-01-01 03:20:03+00:00
# 79 2013-12-31 08:00:00+00:00 2014-01-01 16:50:02+00:00
# 82 2013-12-31 08:00:00+00:00 2014-01-01 13:20:04+00:00
#
#     differenza_giorni_inizio  giorni_differenza_totale  \
# 0                         44                        53
# 1                         84                        96
# 4                         43                        57
# 12                        51                        60
# 13                        84                        90
# 71                        17                        73
# 74                        13                        57
# 75                        27                        51
# 79                        49                        62
# 82                        55                        59
#
#     differenza_giorni_alla_fine
# 0                             9
# 1                            11
# 4                            14
# 12                            8
# 13                            5
# 71                           55
# 74                           43
# 75                           24
# 79                           12
# 82                            3

# %%
loans_differenzaanni['differenza_giorni_inizio'] = (loans_utili_no_missing['planned_expiration_time_date'] - loans_utili_no_missing['inizio_anno']).dt.days
loans_utili_no_missing.head(10)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#    loan_id        disburse_time_date planned_expiration_time_date  \
# 0   657307 2013-12-22 08:00:00+00:00    2014-02-14 03:30:06+00:00
# 1   657259 2013-12-20 08:00:00+00:00    2014-03-26 22:25:07+00:00
# 2   658010 2014-01-09 08:00:00+00:00    2014-02-15 21:10:05+00:00
# 3   659347 2014-01-17 08:00:00+00:00    2014-02-21 03:10:02+00:00
# 4   656933 2013-12-17 08:00:00+00:00    2014-02-13 06:10:02+00:00
# 5   659605 2014-01-15 08:00:00+00:00    2014-02-20 02:30:07+00:00
# 6   660240 2014-01-20 08:00:00+00:00    2014-02-21 07:50:11+00:00
# 7   661601 2014-01-10 08:00:00+00:00    2014-02-25 09:50:03+00:00
# 8   661960 2014-01-23 08:00:00+00:00    2014-02-26 00:10:03+00:00
# 9   662117 2014-01-10 08:00:00+00:00    2014-03-19 13:40:02+00:00
#
#    loan_amount  disburse_year  planned_expiration_year  differenza_anni  \
# 0        125.0           2013                     2014                1
# 1        400.0           2013                     2014                1
# 2        400.0           2014                     2014                0
# 3        625.0           2014                     2014                0
# 4        425.0           2013                     2014                1
# 5        350.0           2014                     2014                0
# 6        125.0           2014                     2014                0
# 7       1600.0           2014                     2014                0
# 8        350.0           2014                     2014                0
# 9       1825.0           2014                     2014                0
#
#                   fine_anno               inizio_anno  differenza_giorni  \
# 0 2013-12-31 08:00:00+00:00 2014-01-01 03:30:06+00:00                  9
# 1 2013-12-31 08:00:00+00:00 2014-01-01 22:25:07+00:00                 11
# 2 2014-12-31 08:00:00+00:00 2014-01-01 21:10:05+00:00                356
# 3 2014-12-31 08:00:00+00:00 2014-01-01 03:10:02+00:00                348
# 4 2013-12-31 08:00:00+00:00 2014-01-01 06:10:02+00:00                 14
# 5 2014-12-31 08:00:00+00:00 2014-01-01 02:30:07+00:00                350
# 6 2014-12-31 08:00:00+00:00 2014-01-01 07:50:11+00:00                345
# 7 2014-12-31 08:00:00+00:00 2014-01-01 09:50:03+00:00                355
# 8 2014-12-31 08:00:00+00:00 2014-01-01 00:10:03+00:00                342
# 9 2014-12-31 08:00:00+00:00 2014-01-01 13:40:02+00:00                355
#
#    differenza_giorni_alla_fine  differenza_giorni_inizio  \
# 0                            9                        44
# 1                           11                        84
# 2                          356                        45
# 3                          348                        51
# 4                           14                        43
# 5                          350                        50
# 6                          345                        51
# 7                          355                        55
# 8                          342                        56
# 9                          355                        77
#
#    giorni_differenza_totale
# 0                        53
# 1                        96
# 2                        37
# 3                        34
# 4                        57
# 5                        35
# 6                        31
# 7                        46
# 8                        33
# 9                        68

# %%
loans_differenzaanni['giorni_differenza_totale'] = (loans_differenzaanni['planned_expiration_time_date'] - loans_differenzaanni['disburse_time_date']).dt.days
loans_differenzaanni.head(10)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#     loan_id        disburse_time_date planned_expiration_time_date  \
# 0    657307 2013-12-22 08:00:00+00:00    2014-02-14 03:30:06+00:00
# 1    657259 2013-12-20 08:00:00+00:00    2014-03-26 22:25:07+00:00
# 4    656933 2013-12-17 08:00:00+00:00    2014-02-13 06:10:02+00:00
# 12   660363 2013-12-23 08:00:00+00:00    2014-02-21 17:10:02+00:00
# 13   661165 2013-12-26 08:00:00+00:00    2014-03-26 22:24:34+00:00
# 71   808452 2014-11-06 08:00:00+00:00    2015-01-18 17:50:04+00:00
# 74  1204329 2016-11-18 08:00:00+00:00    2017-01-14 14:20:02+00:00
# 75  1212312 2016-12-07 08:00:00+00:00    2017-01-28 03:20:03+00:00
# 79   659111 2013-12-19 08:00:00+00:00    2014-02-19 16:50:02+00:00
# 82   661912 2013-12-28 08:00:00+00:00    2014-02-25 13:20:04+00:00
#
#     loan_amount  disburse_year  planned_expiration_year  differenza_anni  \
# 0         125.0           2013                     2014                1
# 1         400.0           2013                     2014                1
# 4         425.0           2013                     2014                1
# 12       1175.0           2013                     2014                1
# 13        300.0           2013                     2014                1
# 71        225.0           2014                     2015                1
# 74        725.0           2016                     2017                1
# 75       3750.0           2016                     2017                1
# 79        875.0           2013                     2014                1
# 82        625.0           2013                     2014                1
#
#                    fine_anno               inizio_anno  \
# 0  2013-12-31 08:00:00+00:00 2014-01-01 03:30:06+00:00
# 1  2013-12-31 08:00:00+00:00 2014-01-01 22:25:07+00:00
# 4  2013-12-31 08:00:00+00:00 2014-01-01 06:10:02+00:00
# 12 2013-12-31 08:00:00+00:00 2014-01-01 17:10:02+00:00
# 13 2013-12-31 08:00:00+00:00 2014-01-01 22:24:34+00:00
# 71 2014-12-31 08:00:00+00:00 2015-01-01 17:50:04+00:00
# 74 2016-12-31 08:00:00+00:00 2017-01-01 14:20:02+00:00
# 75 2016-12-31 08:00:00+00:00 2017-01-01 03:20:03+00:00
# 79 2013-12-31 08:00:00+00:00 2014-01-01 16:50:02+00:00
# 82 2013-12-31 08:00:00+00:00 2014-01-01 13:20:04+00:00
#
#     differenza_giorni_inizio  giorni_differenza_totale  \
# 0                         44                        53
# 1                         84                        96
# 4                         43                        57
# 12                        51                        60
# 13                        84                        90
# 71                        17                        73
# 74                        13                        57
# 75                        27                        51
# 79                        49                        62
# 82                        55                        59
#
#     differenza_giorni_alla_fine
# 0                             9
# 1                            11
# 4                            14
# 12                            8
# 13                            5
# 71                           55
# 74                           43
# 75                           24
# 79                           12
# 82                            3

# %%
loans_differenzaanni['giorni_di_mezzo'] = loans_differenzaanni['giorni_differenza_totale'] - loans_differenzaanni['differenza_giorni_inizio'] - loans_differenzaanni['differenza_giorni_alla_fine']
loans_differenzaanni
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#          loan_id        disburse_time_date planned_expiration_time_date  \
# 0         657307 2013-12-22 08:00:00+00:00    2014-02-14 03:30:06+00:00
# 1         657259 2013-12-20 08:00:00+00:00    2014-03-26 22:25:07+00:00
# 4         656933 2013-12-17 08:00:00+00:00    2014-02-13 06:10:02+00:00
# 12        660363 2013-12-23 08:00:00+00:00    2014-02-21 17:10:02+00:00
# 13        661165 2013-12-26 08:00:00+00:00    2014-03-26 22:24:34+00:00
# ...          ...                       ...                          ...
# 1419602   988180 2015-11-23 08:00:00+00:00    2016-01-02 01:00:03+00:00
# 1419603   988213 2015-11-24 08:00:00+00:00    2016-01-02 16:40:07+00:00
# 1419604   989109 2015-11-13 08:00:00+00:00    2016-01-03 22:20:04+00:00
# 1419605   989143 2015-11-03 08:00:00+00:00    2016-01-05 08:50:02+00:00
# 1419606   989240 2015-11-03 08:00:00+00:00    2016-01-03 20:50:06+00:00
#
#          loan_amount  disburse_year  planned_expiration_year  differenza_anni  \
# 0              125.0           2013                     2014                1
# 1              400.0           2013                     2014                1
# 4              425.0           2013                     2014                1
# 12            1175.0           2013                     2014                1
# 13             300.0           2013                     2014                1
# ...              ...            ...                      ...              ...
# 1419602        400.0           2015                     2016                1
# 1419603        300.0           2015                     2016                1
# 1419604       2425.0           2015                     2016                1
# 1419605        100.0           2015                     2016                1
# 1419606        175.0           2015                     2016                1
#
#                         fine_anno               inizio_anno  \
# 0       2013-12-31 08:00:00+00:00 2014-01-01 03:30:06+00:00
# 1       2013-12-31 08:00:00+00:00 2014-01-01 22:25:07+00:00
# 4       2013-12-31 08:00:00+00:00 2014-01-01 06:10:02+00:00
# 12      2013-12-31 08:00:00+00:00 2014-01-01 17:10:02+00:00
# 13      2013-12-31 08:00:00+00:00 2014-01-01 22:24:34+00:00
# ...                           ...                       ...
# 1419602 2015-12-31 08:00:00+00:00 2016-01-01 01:00:03+00:00
# 1419603 2015-12-31 08:00:00+00:00 2016-01-01 16:40:07+00:00
# 1419604 2015-12-31 08:00:00+00:00 2016-01-01 22:20:04+00:00
# 1419605 2015-12-31 08:00:00+00:00 2016-01-01 08:50:02+00:00
# 1419606 2015-12-31 08:00:00+00:00 2016-01-01 20:50:06+00:00
#
#          differenza_giorni_inizio  giorni_differenza_totale  \
# 0                              44                        53
# 1                              84                        96
# 4                              43                        57
# 12                             51                        60
# 13                             84                        90
# ...                           ...                       ...
# 1419602                         1                        39
# 1419603                         1                        39
# 1419604                         2                        51
# 1419605                         4                        63
# 1419606                         2                        61
#
#          differenza_giorni_alla_fine  giorni_di_mezzo
# 0                                  9                0
# 1                                 11                1
# 4                                 14                0
# 12                                 8                1
# 13                                 5                1
# ...                              ...              ...
# 1419602                           38                0
# 1419603                           37                1
# 1419604                           48                1
# 1419605                           58                1
# 1419606                           58                1
#
# [152157 rows x 13 columns]

# %%
lista_per_gli_anni = []
giorni_in_un_anno = 365

# %%
def function(dataframe):
    global lista_per_gli_anni
    disburse_year = dataframe['disburse_year']
    planned_expiration_year = dataframe['planned_expiration_year']
    for i in range(disburse_year, planned_expiration_year, 1):
        x_year_ammontare = (dataframe['loan_amount']*dataframe['differenza_giorni_alla_fine']) / dataframe['giorni_differenza_totale']
        risultato = {'prestito_ammontare': x_year_ammontare, 'year':disburse_year}
        lista_per_gli_anni.append(risultato)
        dataframe['differenza_giorni_alla_fine'] = giorni_in_un_anno
        disburse_year = disburse_year+1
        x_year_ammontare = (dataframe['loan_amount']*dataframe['differenza_giorni_inizio']) / dataframe['giorni_differenza_totale']
        anni = dataframe['planned_expiration_year']
        risultato = {'prestito_ammontare':x_year_ammontare, 'year':anni}
        lista_per_gli_anni.append(risultato)
    return

# %%
loans_differenzaanni.apply(lambda i : function(i), axis = 'columns')
# Out:
# 0          None
# 1          None
# 4          None
# 12         None
# 13         None
#            ...
# 1419602    None
# 1419603    None
# 1419604    None
# 1419605    None
# 1419606    None
# Length: 152157, dtype: object

# %%
lista_per_gli_anni
dataframe_anni_prestiti = pd.DataFrame(lista_per_gli_anni)
dataframe_anni_prestiti.head()
# Out:
#    prestito_ammontare  year
# 0           21.226415  2013
# 1          103.773585  2014
# 2           45.833333  2013
# 3          350.000000  2014
# 4          104.385965  2013

# %%
data_frame_anni_prestiti_diff = round(dataframe_anni_prestiti.groupby('year').sum(),0)
data_frame_anni_prestiti_diff.head(10)
# Out:
#       prestito_ammontare
# year
# 2011            844677.0
# 2012          10160079.0
# 2013          29103302.0
# 2014          38548976.0
# 2015          29592852.0
# 2016          25023665.0
# 2017          28028672.0
# 2018           8606527.0

# %%
loans_nodifferenzaanni.head()
# Out:
#    loan_id        disburse_time_date planned_expiration_time_date  \
# 2   658010 2014-01-09 08:00:00+00:00    2014-02-15 21:10:05+00:00
# 3   659347 2014-01-17 08:00:00+00:00    2014-02-21 03:10:02+00:00
# 5   659605 2014-01-15 08:00:00+00:00    2014-02-20 02:30:07+00:00
# 6   660240 2014-01-20 08:00:00+00:00    2014-02-21 07:50:11+00:00
# 7   661601 2014-01-10 08:00:00+00:00    2014-02-25 09:50:03+00:00
#
#    loan_amount  disburse_year  planned_expiration_year  differenza_anni
# 2        400.0           2014                     2014                0
# 3        625.0           2014                     2014                0
# 5        350.0           2014                     2014                0
# 6        125.0           2014                     2014                0
# 7       1600.0           2014                     2014                0

# %%
loans_nodifferenzaanni['year'] = loans_nodifferenzaanni['disburse_year']
dataframe_prestiti_anni_stessoanno = loans_nodifferenzaanni.groupby('disburse_year')['loan_amount'].sum()
dataframe_prestiti_anni_stessoanno.head(10)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# disburse_year
# 2012    104138000.0
# 2013     99878775.0
# 2014    123149050.0
# 2015    135779450.0
# 2016    138206675.0
# 2017    151284475.0
# 2018       710425.0
# Name: loan_amount, dtype: float64

# %%
dataframe_prestiti_anni_stessoanno_df = pd.DataFrame(dataframe_prestiti_anni_stessoanno).reset_index()
dataframe_prestiti_anni_stessoanno_df.head(10)
# Out:
#    disburse_year  loan_amount
# 0           2012  104138000.0
# 1           2013   99878775.0
# 2           2014  123149050.0
# 3           2015  135779450.0
# 4           2016  138206675.0
# 5           2017  151284475.0
# 6           2018     710425.0

# %%
ammontare_totale_per_anni = pd.merge(dataframe_prestiti_anni_stessoanno_df, data_frame_anni_prestiti_diff, left_on = "disburse_year", right_on = 'year')
ammontare_totale_per_anni.head()
# Out:
#    disburse_year  loan_amount  prestito_ammontare
# 0           2012  104138000.0          10160079.0
# 1           2013   99878775.0          29103302.0
# 2           2014  123149050.0          38548976.0
# 3           2015  135779450.0          29592852.0
# 4           2016  138206675.0          25023665.0

# %%
ammontare_totale_per_anni_def = ammontare_totale_per_anni.groupby('disburse_year')[['loan_amount', 'prestito_ammontare']].sum()
ammontare_totale_per_anni.head()
# Out:
#    disburse_year  loan_amount  prestito_ammontare
# 0           2012  104138000.0          10160079.0
# 1           2013   99878775.0          29103302.0
# 2           2014  123149050.0          38548976.0
# 3           2015  135779450.0          29592852.0
# 4           2016  138206675.0          25023665.0

# %%
ammontare_totale_per_anni_def['totale_ammontare'] = ammontare_totale_per_anni_def['loan_amount'] + ammontare_totale_per_anni_def['prestito_ammontare']
ammontare_totale_per_anni_def.reset_index().head()
# Out:
#    disburse_year  loan_amount  prestito_ammontare  totale_ammontare
# 0           2012  104138000.0          10160079.0       114298079.0
# 1           2013   99878775.0          29103302.0       128982077.0
# 2           2014  123149050.0          38548976.0       161698026.0
# 3           2015  135779450.0          29592852.0       165372302.0
# 4           2016  138206675.0          25023665.0       163230340.0

# %%
ammontare_totale_per_anni_def_totale = ammontare_totale_per_anni_def[["disburse_year", "totale_ammontare"]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-182-40300921651a> in <module>
# ----> 1 ammontare_totale_per_anni_def_totale = ammontare_totale_per_anni_def[["disburse_year", "totale_ammontare"]]
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2984             if is_iterator(key):
#    2985                 key = list(key)
# -> 2986             indexer = self.loc._convert_to_indexer(key, axis=1, raise_missing=True)
#    2987
#    2988         # take() does not accept boolean indexers
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _convert_to_indexer(self, obj, axis, is_setter, raise_missing)
#    1283                 # When setting, missing keys are not allowed, even with .loc:
#    1284                 kwargs = {"raise_missing": True if is_setter else raise_missing}
# -> 1285                 return self._get_listlike_indexer(obj, axis, **kwargs)[1]
#    1286         else:
#    1287             try:
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1090
#    1091         self._validate_read_indexer(
# -> 1092             keyarr, indexer, o._get_axis_number(axis), raise_missing=raise_missing
#    1093         )
#    1094         return keyarr, indexer
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1183             if not (self.name == "loc" and not raise_missing):
#    1184                 not_found = list(set(key) - set(ax))
# -> 1185                 raise KeyError("{} not in index".format(not_found))
#    1186
#    1187             # we skip the warning on Categorical/Interval
#
# KeyError: "['disburse_year'] not in index"
